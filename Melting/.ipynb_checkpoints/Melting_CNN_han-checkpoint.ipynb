# %% [markdown]
# <p align="center">
#     <img src="https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/076ffad6-abf4-431b-af15-10373ba06182" align="right">
# </p>

# %% [markdown]
# # ***용해탱크 시계열 데이터 AI 실습***
#
# **제목:** 용해탱크의 품질 예측을 위한 AI 데이터셋 가이드북  <br>
# **Description:** 용해탱크로부터 수집한 데이터를 전처리하고, 딥러닝 모델을 사용하여 품질 예측을 수행합니다
#
# 본 자료는 정부에서 운영하는 아래의 KAMP(한국인공지능제조플랫폼)의 데이터 및 예제를 수정한 교육자료입니다.
#
# 중소벤처기업부, Korea AI Manufacturing Platform(KAMP), 용해탱크 AI 데이터셋, KAIST(㈜ 임픽스, 한양대학교 산학협력단, ㈜아큐라소프트), 2020.12.14., www.kamp-ai.kr
#
# https://www.kamp-ai.kr/aidataDetail?AI_SEARCH=%EC%9A%A9%ED%95%B4%ED%83%B1%ED%81%AC&page=1&DATASET_SEQ=8&EQUIP_SEL=&GUBUN_SEL=&FILE_TYPE_SEL=&WDATE_SEL=

# %% [markdown]
# ※ 분석하기에 앞서 다음과 같은 가상환경이 구축되어있는지 확인해주세요. <br>
# Python 버전 : 3.10.12

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## 1. 분석 개요
#
# ### 1.1 분석 배경
#
# **공정(설비) 개요:**
# - 용해공정은 분말 원재료를 액상 원재료에 녹이는 공정으로, 식품, 화학, 석유화학 등 다양한 분야에서 적용됩니다.
# - 용해공정의 품질은 후공정 및 완제품의 품질에 큰 영향을 미치며, 균일한 혼합물이 되도록 하는 것이 중요합니다.
#
# ![melting_1.png](https://www.kamp-ai.kr/mnt/dataset/8/images/1.png)<br>
# <center>[용해공정 설비(사진)]</center> <br>
#
# **이슈사항(Pain Point):**
# - 공정에서 설정한 기준값에 따라 운영하더라도 다양한 변수로 인해 품질이 변동됩니다.
# - 작업자의 경험과 노하우에 의존하여 대처하는 경우가 많으며, 이로 인해 일관된 품질 관리가 어려운 경우가 있습니다.
#
# ### 1.2 분석 목표
#
# **분석 목표:**
# - 용해탱크의 운영 데이터를 통해 최종 제품의 품질을 예측합니다.
# - 머신러닝 모델을 사용하여 공정 중 발생할 수 있는 불량을 예측하고, 이를 통해 품질을 개선하고자 합니다.
#
# **제조 데이터 분석 기대효과:**
# - 데이터 분석을 통해 설비 운영 조건에 따른 생산 품질을 예측하고, 불량률을 낮추기 위한 최적의 운영 조건을 도출합니다.
#
# ### 1.3 제조데이터 소개
#
# **데이터 수집 방법:**
#  - 제조 분야 : 분무건조공법을 이용한 분말유크림 제조
#  - 제조 공정명 : 용해혼합
#  - 수집장비 : PLC(설비데이터) 및 DBMS(품질데이터)
#  - 수집기간 : 2020년 3월 4일 ~ 2020년 4월 30일 (약 2개월)
#  - 수집주기 : 사이클타임 약 6초
#
# **데이터 유형/구조:**<br>
# ![melting_2.png](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/44ee0db6-aed1-4593-b4a3-40788741af18)<br>
#
#  - 데이터 크기, 데이터 수량: 7개 컬럼, 836,200개의 관측치
#  - 데이터 속성 정의 표:<br>
# ![melting_3.png](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/2c4d4837-9854-4d80-bc71-f6a7b34d0822)<br>
#  - 독립변수/종속변수 정의:<br>
#  ![melting_4.png](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/cfe8ce2f-6ecd-43f4-8bea-bc96ed0810c4)<br>

# %% [markdown]
# ## 2. 분석 실습

# %% [markdown]
# ### 2-1. 라이브러리 / 데이터 불러오기

# %% [markdown]
# #### 필요한 라이브러리 설치 및 불러오기

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (24.0)

# %%
# !pip install tensorflow==2.16.1 pandas==2.2.2 numpy==1.26.4 matplotlib==3.9.0 scikit-learn==1.5.0 imbalanced-learn==0.9.0
# Out:
# Requirement already satisfied: tensorflow==2.16.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (2.16.1)
# Requirement already satisfied: pandas==2.2.2 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy==1.26.4 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib==3.9.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (3.9.0)
# Requirement already satisfied: scikit-learn==1.5.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (1.5.0)
# Requirement already satisfied: imbalanced-learn==0.9.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (0.9.0)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow==2.16.1) (2.16.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (4.52.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from scikit-learn==1.5.0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from scikit-learn==1.5.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from scikit-learn==1.5.0) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (4.12.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.64.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.43.0)
# Requirement already satisfied: rich in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (13.7.1)
# Requirement already satisfied: namex in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.0.8)
# Requirement already satisfied: optree in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.1.2)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
import tensorflow

# %% [markdown]
# #### 데이터 불러오기

# %%
data_path = './dataset/melting_tank.csv'  # 실제 데이터 경로로 변경하세요
data = pd.read_csv(data_path)

# %% [markdown]
# ### 2-2. 데이터 특성 파악

# %% [markdown]
# #### 데이터 기본 구조 파악

# %%
print(data.head())
# Out:
#             STD_DT  NUM  MELT_TEMP  MOTORSPEED  MELT_WEIGHT  INSP TAG
# 0  2020-03-04 0:00    0        489         116          631  3.19  OK
# 1  2020-03-04 0:00    1        433          78          609  3.19  OK
# 2  2020-03-04 0:00    2        464         154          608  3.19  OK
# 3  2020-03-04 0:00    3        379         212          606  3.19  OK
# 4  2020-03-04 0:00    4        798        1736          604  3.21  OK

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835200 entries, 0 to 835199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STD_DT       835200 non-null  object
#  1   NUM          835200 non-null  int64
#  2   MELT_TEMP    835200 non-null  int64
#  3   MOTORSPEED   835200 non-null  int64
#  4   MELT_WEIGHT  835200 non-null  int64
#  5   INSP         835200 non-null  float64
#  6   TAG          835200 non-null  object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 44.6+ MB
# None

# %%
print(data.describe())
# Out:
#                  NUM      MELT_TEMP     MOTORSPEED    MELT_WEIGHT  \
# count  835200.000000  835200.000000  835200.000000  835200.000000
# mean   417599.500000     509.200623     459.782865     582.962125
# std    241101.616751     128.277519     639.436413    1217.604433
# min         0.000000     308.000000       0.000000       0.000000
# 25%    208799.750000     430.000000     119.000000     186.000000
# 50%    417599.500000     469.000000     168.000000     383.000000
# 75%    626399.250000     502.000000     218.000000     583.000000
# max    835199.000000     832.000000    1804.000000   55252.000000
#
#                 INSP
# count  835200.000000
# mean        3.194853
# std         0.011822
# min         3.170000
# 25%         3.190000
# 50%         3.190000
# 75%         3.200000
# max         3.230000

# %% [markdown]
# #### 시간 정보 datetime 형태 변환 및 인덱스 지정

# %%
data['STD_DT'] = pd.to_datetime(data['STD_DT'])

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835200 entries, 0 to 835199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STD_DT       835200 non-null  datetime64[ns]
#  1   NUM          835200 non-null  int64
#  2   MELT_TEMP    835200 non-null  int64
#  3   MOTORSPEED   835200 non-null  int64
#  4   MELT_WEIGHT  835200 non-null  int64
#  5   INSP         835200 non-null  float64
#  6   TAG          835200 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 44.6+ MB
# None

# %%
data = data.set_index(['STD_DT'])

# %%
print(data.head())
# Out:
#             NUM  MELT_TEMP  MOTORSPEED  MELT_WEIGHT  INSP TAG
# STD_DT
# 2020-03-04    0        489         116          631  3.19  OK
# 2020-03-04    1        433          78          609  3.19  OK
# 2020-03-04    2        464         154          608  3.19  OK
# 2020-03-04    3        379         212          606  3.19  OK
# 2020-03-04    4        798        1736          604  3.21  OK

# %% [markdown]
# #### Histogram 및 Plot 그리기

# %% [markdown]
# ##### Histogram

# %%
col_names = ['MELT_TEMP', 'MOTORSPEED', 'MELT_WEIGHT', 'INSP', 'TAG']

# 반복문을 시작하기에 앞서 각 그래프의 사이즈를 12x12로 지정
plt.figure(figsize=(12, 12))

# 각 변수에 대해 히스토그램을 그리기 위한 반복문
for i in range(len(col_names)):
    plt.subplot(3, 2, i + 1)
    plt.hist(data[col_names[i]], bins=50, edgecolor='k')
    plt.xticks(rotation=45)
    plt.title(col_names[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot

# %%
# 반복문을 시작하기에 앞서 각 그래프의 사이즈를 12x12로 지정
plt.figure(figsize=(12, 12))

# 각 변수에 대해 plot을 그리기 위한 반복문
for i in range(len(col_names)):
    plt.subplot(3, 2, i + 1)
    plt.plot(data[col_names[i]])
    plt.xticks(rotation=45)
    plt.title(col_names[i])

plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# ##### Plot(0:100 Slicing)

# %%
# 반복문을 시작하기에 앞서 각 그래프의 사이즈를 12x12로 지정
plt.figure(figsize=(12, 12))

# 각 변수에 대해 plot을 그리기 위한 반복문
for i in range(len(col_names)):
    plt.subplot(3, 2, i + 1)
    plt.plot(data[col_names[i]][0:100])
    plt.xticks(rotation=45)
    plt.title(col_names[i])

plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# #### 범주형 변수 인코딩

# %%
label_encoder = LabelEncoder()
data['TAG'] = label_encoder.fit_transform(data['TAG'])

# %%
data['TAG'].value_counts()
# Out:
# TAG
# 1    658133
# 0    177067
# Name: count, dtype: int64

# %% [markdown]
# #### 상관관계 확인

# %%
print(data.corr(method='pearson'))
# Out:
#                   NUM  MELT_TEMP  MOTORSPEED  MELT_WEIGHT      INSP       TAG
# NUM          1.000000   0.000188   -0.000050     0.080079 -0.000524  0.086698
# MELT_TEMP    0.000188   1.000000    0.944929    -0.000336  0.916295  0.310586
# MOTORSPEED  -0.000050   0.944929    1.000000     0.000123  0.887813  0.264693
# MELT_WEIGHT  0.080079  -0.000336    0.000123     1.000000 -0.000005 -0.012084
# INSP        -0.000524   0.916295    0.887813    -0.000005  1.000000  0.272580
# TAG          0.086698   0.310586    0.264693    -0.012084  0.272580  1.000000

# %% [markdown]
# ### 2-3. 데이터 정제(전처리)

# %% [markdown]
# #### 분석에 활용할 칼럼 추출

# %%
data = data[['MELT_TEMP', 'MOTORSPEED', 'INSP', 'TAG']]

# %% [markdown]
# #### 훈련/테스트 데이터 분리

# %%
split_date = int(data.shape[0]*0.7)
train = data[:split_date]
test = data[split_date:]

# %%
train
# Out:
#                      MELT_TEMP  MOTORSPEED  INSP  TAG
# STD_DT
# 2020-03-04 00:00:00        489         116  3.19    1
# 2020-03-04 00:00:00        433          78  3.19    1
# 2020-03-04 00:00:00        464         154  3.19    1
# 2020-03-04 00:00:00        379         212  3.19    1
# 2020-03-04 00:00:00        798        1736  3.21    1
# ...                        ...         ...   ...  ...
# 2020-04-13 14:23:00        748        1737  3.22    1
# 2020-04-13 14:23:00        381         216  3.19    1
# 2020-04-13 14:23:00        474         148  3.19    1
# 2020-04-13 14:23:00        406          68  3.18    1
# 2020-04-13 14:23:00        477         105  3.19    1
#
# [584640 rows x 4 columns]

# %%
train.shape
# Out:
# (584640, 4)

# %%
test.shape
# Out:
# (250560, 4)

# %% [markdown]
# #### 정규화
#
# Min-max normalization는 데이터를 0과 1 사이의 값으로 scaling합니다.
#
# 1) data의 최대값(max)과 최소값(min)을 구한다.
# 2) 정규화할 데이터 값(x)과 앞서 구한 최대값(Xmax), 최소값(Xmin)을 다음의 식에 대입한다.<br>
#
# <img src="https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/c5a29097-0eb4-44a5-b379-2ea9df771095" width="400" height="400"/>

# %%
# 데이터 정규화
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.fit_transform(test)

# %%
train_scaled
# Out:
# array([[0.34541985, 0.06430155, 0.33333333, 1.        ],
#        [0.23854962, 0.04323725, 0.33333333, 1.        ],
#        [0.29770992, 0.08536585, 0.33333333, 1.        ],
#        ...,
#        [0.31679389, 0.08203991, 0.33333333, 1.        ],
#        [0.1870229 , 0.03769401, 0.16666667, 1.        ],
#        [0.32251908, 0.05820399, 0.33333333, 1.        ]])

# %% [markdown]
# #### 독립변수(feature)와 종속변수(label) 분리

# %%
X_train_values = train_scaled[:, :-1]
y_train_values = train_scaled[:, -1]
X_test_values = test_scaled[:, :-1]
y_test_values = test_scaled[:, -1]

# %% [markdown]
# #### Window 정의 함수 생성
#
# Window는 딥러닝을 학습하기 위한 단위로, window size는 timestep과 같다고 생각하면 된다. <br>
# 입력한 timestep만큼의 데이터를 저장하여 과거 값(예를들어, 1~10)을 통해 현재 종속변수를 예측하는 것이다.

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps)])
        ys.append(y[i + time_steps - 1])
    return np.array(Xs), np.array(ys)

# %%
TIME_STEPS = 10

X_train, y_train = create_dataset(X_train_values, y_train_values, TIME_STEPS)
X_test, y_test = create_dataset(X_test_values, y_test_values, TIME_STEPS)

# %%
X_test.shape
# Out:
# (250550, 10, 3)

# %%
y_test.shape
# Out:
# (250550,)

# %% [markdown]
# ### 2-4. 모델 구축 및 훈련

# %% [markdown]
# **CNN**
# - 합성곱 신경망(Convolutional Neural Network, CNN)은 이미지 처리에 주로 사용되는 딥러닝 모델로, 이미지의 패턴과 특징을 자동으로 추출하여 분류 및 인식을 수행합니다.
# - CNN은 이미지 분류, 객체 인식, 얼굴 인식 등 다양한 컴퓨터 비전 작업에서 뛰어난 성능을 보입니다.<br>
# - CNN의 주요 구성 요소
#   1. 합성곱 층 (Convolutional Layer): 입력 이미지에 여러 개의 필터를 적용하여 특징 맵을 생성합니다.
#   2. 풀링 층 (Pooling Layer): 특징 맵의 크기를 줄여 계산량을 감소시키고, 중요한 특징을 추출합니다.
#   3. 완전 연결 층 (Fully Connected Layer): 추출된 특징을 기반으로 최종 출력을 생성합니다.<br>
#
#     |<b>CNN의 기본 구조</b> |
#     | :--: |
#     | ![](https://media.licdn.com/dms/image/D5612AQGOui8XZUZJSA/article-cover_image-shrink_600_2000/0/1680532048475?e=1722470400&v=beta&t=0wvlOsASQ4GVANk_DcYNZC4XEeHV4X9hf0JhtCpEiNQ)|
#     |출처: https://www.linkedin.com/pulse/what-convolutional-neural-network-cnn-deep-learning-nafiz-shahriar/|
#
# **1-D CNN**
# - 1-D CNN (1차원 합성곱 신경망)은 시계열 데이터, 신호 처리, 텍스트 데이터 등 1차원 데이터를 처리하는 데 적합한 모델입니다.
# - 2차원 이미지를 처리하는 일반적인 CNN과 달리, 1-D CNN은 1차원 데이터의 패턴을 학습하고 특징을 추출합니다.
#
#     |<b>1-D CNN의 기본 구조</b> |
#     | :--: |
#     | ![](https://miro.medium.com/v2/resize:fit:1400/1*iJyzEak-RGfpcBC9v-8oAg.png)|
#     |출처: https://www.google.com/url?sa=i&url=https%3A%2F%2Ftowardsdatascience.com%2Fhow-to-use-convolutional-neural-networks-for-time-series-classification-56b1b0a07a57&psig=AOvVaw1HHYhpGxsMj5Gws5uQbKr9&ust=1717153551480000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCPDSvq2etYYDFQAAAAAdAAAAABAE|

# %% [markdown]
# ### 1-D CNN 모델 구축

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, Flatten, Dense, Dropout

# 1D-CNN 모델 정의
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(TIME_STEPS, X_train.shape[2])))
model.add(GlobalMaxPooling1D())
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\Han\Miniconda3\envs\hyundai_equip_6\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #### 모델 학습

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=50, validation_split=0.2)
# Out:
# Epoch 1/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step - accuracy: 0.7131 - loss: 0.5378 - val_accuracy: 0.6272 - val_loss: 0.5977
# Epoch 2/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7237 - loss: 0.5110 - val_accuracy: 0.5779 - val_loss: 0.5695
# Epoch 3/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7262 - loss: 0.5085 - val_accuracy: 0.5747 - val_loss: 0.5697
# Epoch 4/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7275 - loss: 0.5054 - val_accuracy: 0.5822 - val_loss: 0.5654
# Epoch 5/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7277 - loss: 0.5041 - val_accuracy: 0.5813 - val_loss: 0.5690
# Epoch 6/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7278 - loss: 0.5039 - val_accuracy: 0.5949 - val_loss: 0.5722
# Epoch 7/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7282 - loss: 0.5032 - val_accuracy: 0.5760 - val_loss: 0.5554
# Epoch 8/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7276 - loss: 0.5023 - val_accuracy: 0.5836 - val_loss: 0.5573
# Epoch 9/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7278 - loss: 0.5026 - val_accuracy: 0.5847 - val_loss: 0.5556
# Epoch 10/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7271 - loss: 0.5027 - val_accuracy: 0.5872 - val_loss: 0.5514
# Epoch 11/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7274 - loss: 0.5023 - val_accuracy: 0.5957 - val_loss: 0.5474
# Epoch 12/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7292 - loss: 0.5002 - val_accuracy: 0.5893 - val_loss: 0.5489
# Epoch 13/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7283 - loss: 0.5014 - val_accuracy: 0.6010 - val_loss: 0.5546
# Epoch 14/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7264 - loss: 0.5021 - val_accuracy: 0.5865 - val_loss: 0.5496
# Epoch 15/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7278 - loss: 0.5008 - val_accuracy: 0.5954 - val_loss: 0.5507
# Epoch 16/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7286 - loss: 0.5001 - val_accuracy: 0.5843 - val_loss: 0.5622
# Epoch 17/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7284 - loss: 0.5008 - val_accuracy: 0.5892 - val_loss: 0.5533
# Epoch 18/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7275 - loss: 0.5010 - val_accuracy: 0.5922 - val_loss: 0.5492
# Epoch 19/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7276 - loss: 0.5007 - val_accuracy: 0.5876 - val_loss: 0.5543
# Epoch 20/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7277 - loss: 0.5002 - val_accuracy: 0.5883 - val_loss: 0.5536

# %% [markdown]
# #### 손실 그래프 시각화

# %%
# 손실 그래프 시각화
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 2-5. 모델 평가

# %%
y_pred = model.predict(X_test)
y_pred_class = (y_pred > 0.5).astype("int32")

print(classification_report(y_test, y_pred_class))
print(confusion_matrix(y_test, y_pred_class))
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred_class), display_labels=label_encoder.classes_)
disp.plot()
plt.show()
# Out:
# 7830/7830 ━━━━━━━━━━━━━━━━━━━━ 5s 609us/step
#               precision    recall  f1-score   support
#
#          0.0       0.01      0.10      0.01      2940
#          1.0       0.99      0.79      0.88    247610
#
#     accuracy                           0.78    250550
#    macro avg       0.50      0.45      0.44    250550
# weighted avg       0.98      0.78      0.87    250550
#
# [[   307   2633]
#  [ 52437 195173]]

# %%
# F1 Score 및 Accuracy 계산
accuracy = accuracy_score(y_test, y_pred_class)
f1 = f1_score(y_test, y_pred_class)

print(f'Accuracy: {accuracy:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.7802
# F1 Score: 0.8764

# %% [markdown]
# ### 2-6. 모델 개선(1) - 모델 고도화, 전처리 수정

# %% [markdown]
# #### 추가 레이어 사용

# %% [markdown]
# **BatchNormalization**
# - BatchNormalization은 신경망의 각 층에서 미니 배치의 평균과 표준편차를 이용하여 입력을 정규화하는 방법입니다.
# - 이는 학습 과정의 안정성과 속도를 높이고, 초기화에 덜 민감하게 합니다.
#
#     |<b>BatchNormalization</b> |
#     | :--: |
#     | ![](https://gaussian37.github.io/assets/img/dl/concept/batchnorm/4.png)|
#     |출처: https://gaussian37.github.io/dl-concept-batchnorm/|
#
# **Dropout**
# - Dropout은 학습 중에 무작위로 뉴런을 비활성화(즉, "드롭")하여 과적합을 방지하는 정규화 기법입니다.
# - 학습 시 각 뉴런을 일정 확률로 비활성화하고, 예측 시에는 모든 뉴런을 사용합니다.
#
#     |<b>Dropout</b> |
#     | :--: |
#     | ![](https://www.baeldung.com/wp-content/uploads/sites/4/2020/05/2-1-2048x745-1.jpg)|
#     |출처: https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.baeldung.com%2Fcs%2Fml-relu-dropout-layers&psig=AOvVaw2j4B2PJph8_6dstiZWSjWe&ust=1717154169027000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCKD4pI6gtYYDFQAAAAAdAAAAABAE|

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout

# 1D-CNN 모델 정의
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(TIME_STEPS, X_train.shape[2])))
model.add(BatchNormalization())
model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
model.add(BatchNormalization())
model.add(GlobalMaxPooling1D())
model.add(Dense(50, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=20, batch_size=50, validation_split=0.2)

# 손실 그래프 시각화
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# 모델 평가
y_pred = model.predict(X_test)
y_pred_class = (y_pred > 0.5).astype("int32")

print(classification_report(y_test, y_pred_class))
print(confusion_matrix(y_test, y_pred_class))
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred_class), display_labels=label_encoder.classes_)
disp.plot()
plt.show()
# Out:
# Epoch 1/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.7082 - loss: 0.5271 - val_accuracy: 0.5959 - val_loss: 0.5269
# Epoch 2/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.7217 - loss: 0.5037 - val_accuracy: 0.6312 - val_loss: 0.5209
# Epoch 3/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7212 - loss: 0.5012 - val_accuracy: 0.5892 - val_loss: 0.5230
# Epoch 4/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7225 - loss: 0.4993 - val_accuracy: 0.6206 - val_loss: 0.5119
# Epoch 5/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.7204 - loss: 0.5004 - val_accuracy: 0.6362 - val_loss: 0.5032
# Epoch 6/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7213 - loss: 0.4997 - val_accuracy: 0.6259 - val_loss: 0.5003
# Epoch 7/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7209 - loss: 0.5004 - val_accuracy: 0.5984 - val_loss: 0.5034
# Epoch 8/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - accuracy: 0.7228 - loss: 0.4985 - val_accuracy: 0.6193 - val_loss: 0.5119
# Epoch 9/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.7231 - loss: 0.4980 - val_accuracy: 0.7297 - val_loss: 0.5004
# Epoch 10/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7221 - loss: 0.4995 - val_accuracy: 0.6276 - val_loss: 0.5128
# Epoch 11/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7220 - loss: 0.4989 - val_accuracy: 0.6836 - val_loss: 0.5279
# Epoch 12/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7220 - loss: 0.4987 - val_accuracy: 0.5867 - val_loss: 0.5086
# Epoch 13/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.7224 - loss: 0.4975 - val_accuracy: 0.6936 - val_loss: 0.5086
# Epoch 14/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7223 - loss: 0.4972 - val_accuracy: 0.6265 - val_loss: 0.5110
# Epoch 15/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.7223 - loss: 0.4979 - val_accuracy: 0.5937 - val_loss: 0.5076
# Epoch 16/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.7233 - loss: 0.4973 - val_accuracy: 0.6017 - val_loss: 0.5087
# Epoch 17/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.7224 - loss: 0.4981 - val_accuracy: 0.7168 - val_loss: 0.5268
# Epoch 18/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.7228 - loss: 0.4974 - val_accuracy: 0.5915 - val_loss: 0.5057
# Epoch 19/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.7234 - loss: 0.4974 - val_accuracy: 0.6609 - val_loss: 0.5008
# Epoch 20/20
# 9355/9355 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.7230 - loss: 0.4968 - val_accuracy: 0.7103 - val_loss: 0.5413
# 7830/7830 ━━━━━━━━━━━━━━━━━━━━ 7s 831us/step
#               precision    recall  f1-score   support
#
#          0.0       0.02      0.73      0.04      2940
#          1.0       0.99      0.62      0.76    247610
#
#     accuracy                           0.62    250550
#    macro avg       0.51      0.67      0.40    250550
# weighted avg       0.98      0.62      0.75    250550
#
# [[  2149    791]
#  [ 95233 152377]]

# %% [markdown]
# #### 클래스 불균형 문제 해결(SMOTE)

# %%
X_train_values
# Out:
# array([[0.34541985, 0.06430155, 0.33333333],
#        [0.23854962, 0.04323725, 0.33333333],
#        [0.29770992, 0.08536585, 0.33333333],
#        ...,
#        [0.31679389, 0.08203991, 0.33333333],
#        [0.1870229 , 0.03769401, 0.16666667],
#        [0.32251908, 0.05820399, 0.33333333]])

# %%
y_train_values
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train_values, y_train_values)

# %%
pd.Series(y_train_values).value_counts()
# Out:
# 1.0    410516
# 0.0    174124
# Name: count, dtype: int64

# %%
pd.Series(y_res).value_counts()
# Out:
# 1.0    410516
# 0.0    410516
# Name: count, dtype: int64

# %%
# 데이터셋 생성
X_train, y_train = create_dataset(X_res, y_res, TIME_STEPS)

# 모델 재정의 및 학습
model = Sequential()
model.add(LSTM(50, activation='tanh', input_shape=(TIME_STEPS, X_train.shape[2])))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=20, batch_size=50, validation_split=0.2)

# 손실 그래프 시각화
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# 모델 평가
y_pred = model.predict(X_test)
y_pred_class = (y_pred > 0.5).astype("int32")

print(classification_report(y_test, y_pred_class))
print(confusion_matrix(y_test, y_pred_class))
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred_class), display_labels=label_encoder.classes_)
disp.plot()
plt.show()
# Out:
# Epoch 1/20
# C:\Users\Han\Miniconda3\envs\hyundai_equip_6\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 33s 2ms/step - accuracy: 0.7382 - loss: 0.4685 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 2/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.7552 - loss: 0.4339 - val_accuracy: 1.0000 - val_loss: 6.4404e-04
# Epoch 3/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.7551 - loss: 0.4328 - val_accuracy: 1.0000 - val_loss: 1.1919e-04
# Epoch 4/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.7559 - loss: 0.4330 - val_accuracy: 1.0000 - val_loss: 6.1655e-05
# Epoch 5/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.7552 - loss: 0.4338 - val_accuracy: 1.0000 - val_loss: 1.4384e-05
# Epoch 6/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.7563 - loss: 0.4323 - val_accuracy: 1.0000 - val_loss: 2.3840e-05
# Epoch 7/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 33s 2ms/step - accuracy: 0.7557 - loss: 0.4328 - val_accuracy: 1.0000 - val_loss: 6.6139e-06
# Epoch 8/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.7554 - loss: 0.4322 - val_accuracy: 1.0000 - val_loss: 3.4351e-06
# Epoch 9/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.7570 - loss: 0.4318 - val_accuracy: 1.0000 - val_loss: 2.5530e-06
# Epoch 10/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 33s 2ms/step - accuracy: 0.7559 - loss: 0.4324 - val_accuracy: 1.0000 - val_loss: 2.8755e-06
# Epoch 11/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.7567 - loss: 0.4325 - val_accuracy: 1.0000 - val_loss: 2.9818e-06
# Epoch 12/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.7556 - loss: 0.4326 - val_accuracy: 1.0000 - val_loss: 1.7199e-06
# Epoch 13/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.7561 - loss: 0.4326 - val_accuracy: 1.0000 - val_loss: 1.3197e-06
# Epoch 14/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 35s 3ms/step - accuracy: 0.7567 - loss: 0.4316 - val_accuracy: 1.0000 - val_loss: 2.5571e-06
# Epoch 15/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.7558 - loss: 0.4332 - val_accuracy: 1.0000 - val_loss: 1.6161e-06
# Epoch 16/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.7559 - loss: 0.4324 - val_accuracy: 1.0000 - val_loss: 5.2105e-07
# Epoch 17/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.7559 - loss: 0.4329 - val_accuracy: 1.0000 - val_loss: 1.0788e-06
# Epoch 18/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.7569 - loss: 0.4320 - val_accuracy: 1.0000 - val_loss: 7.9816e-07
# Epoch 19/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.7558 - loss: 0.4327 - val_accuracy: 1.0000 - val_loss: 5.0294e-07
# Epoch 20/20
# 13137/13137 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step - accuracy: 0.7563 - loss: 0.4327 - val_accuracy: 1.0000 - val_loss: 3.7651e-07
# 7830/7830 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.04      0.73      0.08      2940
#          1.0       1.00      0.81      0.89    247610
#
#     accuracy                           0.81    250550
#    macro avg       0.52      0.77      0.49    250550
# weighted avg       0.98      0.81      0.88    250550
#
# [[  2155    785]
#  [ 47955 199655]]

# %% [markdown]
# ### 2-7. 모델 개선(2) - 하이퍼파라미터 튜닝

# %%
# 모델 재정의 및 학습
model = Sequential()

# Conv1D와 BatchNormalization을 반복해서 추가
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(TIME_STEPS, X_train.shape[2])))
model.add(BatchNormalization())
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(GlobalMaxPooling1D())

# Dense 레이어 추가
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))


model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=20, batch_size=50, validation_split=0.2)

# 손실 그래프 시각화
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# 모델 평가
y_pred = model.predict(X_test)
y_pred_class = (y_pred > 0.5).astype("int32")

print(classification_report(y_test, y_pred_class))
print(confusion_matrix(y_test, y_pred_class))
