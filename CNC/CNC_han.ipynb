# %% [markdown]
# <p align="center">
#     <img src="https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/076ffad6-abf4-431b-af15-10373ba06182" align="right">
# </p>

# %% [markdown]
# # ***CNC 머신 시계열 데이터 AI 실습***
#
# **제목:** CNC 머신 품질 예측을 위한 AI 실습  <br>
# **Description:** CNC 머신으로부터 수집한 데이터를 전처리하고, 딥러닝 모델을 사용하여 품질 예측을 수행합니다.
#
# 본 자료는 정부에서 운영하는 아래의 KAMP(한국인공지능제조플랫폼)의 데이터 및 예제를 수정한 교육자료입니다.
#
# 중소벤처기업부, Korea AI Manufacturing Platform(KAMP), CNC 머신 AI 데이터셋, KAIST(울산과학기술원, ㈜이피엠솔루션즈), 2020.12.14., www.kamp-ai.kr
#
# https://www.kamp-ai.kr/aidataDetail?AI_SEARCH=CNC+%EB%A8%B8%EC%8B%A0&page=1&DATASET_SEQ=3&EQUIP_SEL=&GUBUN_SEL=&FILE_TYPE_SEL=&WDATE_SEL=

# %% [markdown]
# ※ 분석하기에 앞서 다음과 같은 가상환경이 구축되어있는지 확인해주세요. <br>
# Python 버전 : 3.10.12

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## 1. 분석 개요
#
# ### 1.1 분석 배경
#
# **공정(설비) 개요:**
# - CNC(Computerized Numerical Control) 가공은 컴퓨터 프로그램을 이용하여 기계의 움직임을 제어하는 정밀 가공 공정입니다.
# - 주로 금속, 플라스틱, 목재 등 다양한 재료를 가공하는 데 사용되며, 복잡한 형상의 부품을 높은 정밀도로 제작할 수 있습니다.
# - 일반적인 CNC 기계에는 선반, 밀링 머신, 드릴링 머신 등이 포함됩니다.
#
# ![image](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/2d412df5-461d-489d-8c2d-5779dd62ad2d)<br>
# <center>[용해공정 설비(사진)]</center> <br>
#
# **이슈사항(Pain Point):**
# - CNC 절삭공구는 마찰과 절삭력 변화로 마모되거나 파손되어 가공 정밀도가 떨어질 수 있습니다.
# - 공정 중 다양한 변수로 인해 품질이 변동되며, 제품 성형 후에야 불량 여부를 확인할 수 있어 일관된 품질 관리가 어렵습니다.
#
# ### 1.2 분석 목표
#
# **분석 목표:**
# - CNC 설비와 네트워크 연결을 통해 실제 가공생산데이터를 수집하여 공구수명에 따른 가공불량 예측을 딥러닝 알고리즘을 활용하여 해결하고자합니다.
#
# **제조 데이터 분석 기대효과:**
# - 데이터 분석을 통해 설비 운영 조건에 따른 생산 품질을 예측하고, 불량률을 낮추기 위한 최적의 운영 조건을 도출합니다.
#
# ### 1.3 제조데이터 소개
#
# **데이터 수집 방법:**
# - 제조 분야 : 자동차 부품
# - 제조 공정명 : 자동차 부품 CNC 가공 공정
# - 수집 장비 : 공장 내 CNC 가공 장비 Data, 조건 및 품질 Data
# - 수집 기간 : 5일
# - 수집 주기 : 1 sec
#
# **데이터 유형/구조:**<br>
#  - 데이터 크기, 데이터 수량: 48개 컬럼, 32,048개의 관측치
#  - 데이터 속성 정의 표:<br>
# ![CNC_1](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/bb3f6ed9-1943-4895-b5a3-83e26187d1c0)<br>
#  - 독립변수/종속변수 정의:<br>
#  ![CNC_3](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/b9cd02c8-ddf0-426a-8031-4bed3a8a45f6)<br>
#  ![CNC_4](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/97af43da-4c2a-49e8-9e99-baf32566a017)

# %% [markdown]
# ## 2. 분석 실습

# %% [markdown]
# ### 2-1. 라이브러리 / 데이터 불러오기

# %% [markdown]
# #### 필요한 라이브러리 설치 및 불러오기

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (24.0)

# %%
# !pip install tensorflow==2.16.1 pandas==2.2.2 numpy==1.26.4 matplotlib==3.9.0 scikit-learn==1.5.0 imbalanced-learn==0.9.0
# Out:
# Requirement already satisfied: tensorflow==2.16.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (2.16.1)
# Requirement already satisfied: pandas==2.2.2 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy==1.26.4 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib==3.9.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (3.9.0)
# Requirement already satisfied: scikit-learn==1.5.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (1.5.0)
# Requirement already satisfied: imbalanced-learn==0.9.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (0.9.0)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow==2.16.1) (2.16.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (4.52.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from matplotlib==3.9.0) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from scikit-learn==1.5.0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from scikit-learn==1.5.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from scikit-learn==1.5.0) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (4.12.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.64.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.43.0)
# Requirement already satisfied: rich in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (13.7.1)
# Requirement already satisfied: namex in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.0.8)
# Requirement already satisfied: optree in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.1.2)

# %%
import glob
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %% [markdown]
# #### 데이터 불러오기

# %%
# CNC 가공 실적 데이터 파일
train_sample = pd.read_csv("./dataset/CNC 비식별화 원본데이터_1209/train.csv", header=0, encoding='utf-8')

# 개별 생산 단위 데이터 파일
path = r'./dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2'  # 경로 설정
all_files = glob.glob(os.path.join(path, "*.csv"))

li_df = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li_df.append(df)

df = pd.concat(li_df, axis=0, ignore_index=True)

# %% [markdown]
# ### 2-2. 데이터 특성 파악

# %% [markdown]
# #### 데이터 기본 구조 파악

# %%
train_sample.head()
# Out:
#    No  material  feedrate  clamp_pressure tool_condition machining_finalized  \
# 0   1  aluminum         6             4.0         unworn                 yes
# 1   2  aluminum        20             4.0         unworn                 yes
# 2   3  aluminum         6             3.0         unworn                 yes
# 3   4  aluminum         6             2.5         unworn                  no
# 4   5  aluminum        20             3.0         unworn                  no
#
#   passed_visual_inspection
# 0                      yes
# 1                      yes
# 2                      yes
# 3                      NaN
# 4                      NaN

# %%
train_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   No                        25 non-null     int64
#  1   material                  25 non-null     object
#  2   feedrate                  25 non-null     int64
#  3   clamp_pressure            25 non-null     float64
#  4   tool_condition            25 non-null     object
#  5   machining_finalized       25 non-null     object
#  6   passed_visual_inspection  19 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.5+ KB

# %%
all_files
# Out:
# ['./dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_01.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_02.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_03.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_04.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_05.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_06.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_07.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_08.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_09.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_10.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_11.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_12.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_13.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_14.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_15.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_16.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_17.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_18.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_19.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_20.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_21.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_22.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_23.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_24.csv',
#  './dataset/CNC 비식별화 원본데이터_1209/CNC Virtual Data set _v2\\experiment_25.csv']

# %%
df.head()
# Out:
#    X_ActualPosition  X_ActualVelocity  X_ActualAcceleration  X_SetPosition  \
# 0             202.0               4.0                  4.00          202.0
# 1             202.0              -6.8               -346.00          202.0
# 2             200.0             -13.8                 -2.25          200.0
# 3             198.0             -14.0                  4.00          198.0
# 4             197.0             -13.9                -14.80          196.0
#
#    X_SetVelocity  X_SetAcceleration  X_CurrentFeedback  X_DCBusVoltage  \
# 0            4.0           4.000000               0.18          0.0207
# 1           -9.6        -354.000000             -10.90          0.1860
# 2          -13.9           3.999905              -8.59          0.1400
# 3          -13.9           3.999905              -6.11          0.1300
# 4          -13.9           4.000095              -5.70          0.1140
#
#    X_OutputCurrent  X_OutputVoltage  ...  S_CurrentFeedback  S_DCBusVoltage  \
# 0              329             2.77  ...              0.524    2.740000e-19
# 1              328            23.30  ...             -0.288    2.740000e-19
# 2              328            30.60  ...              0.524    2.740000e-19
# 3              327            30.30  ...             -0.180    2.740000e-19
# 4              328            30.50  ...              0.226    2.740000e-19
#
#    S_OutputCurrent  S_OutputVoltage  S_OutputPower  S_SystemInertia  \
# 0              329              0.0   6.960000e-07             16.0
# 1              328              0.0  -5.270000e-07             16.0
# 2              328              0.0   9.100000e-07             16.0
# 3              328              0.0   1.070000e-06             16.0
# 4              328              0.0   1.960000e-06             16.0
#
#    M_CURRENT_PROGRAM_NUMBER  M_sequence_number  M_CURRENT_FEEDRATE  \
# 0                         1                  0                  50
# 1                         1                  4                  50
# 2                         1                  7                  50
# 3                         1                  7                  50
# 4                         1                  7                  50
#
#    Machining_Process
# 0           Starting
# 1               Prep
# 2               Prep
# 3               Prep
# 4               Prep
#
# [5 rows x 48 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32048 entries, 0 to 32047
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   X_ActualPosition          32048 non-null  float64
#  1   X_ActualVelocity          32048 non-null  float64
#  2   X_ActualAcceleration      32048 non-null  float64
#  3   X_SetPosition             32048 non-null  float64
#  4   X_SetVelocity             32048 non-null  float64
#  5   X_SetAcceleration         32048 non-null  float64
#  6   X_CurrentFeedback         32048 non-null  float64
#  7   X_DCBusVoltage            32048 non-null  float64
#  8   X_OutputCurrent           32048 non-null  int64
#  9   X_OutputVoltage           32048 non-null  float64
#  10  X_OutputPower             32048 non-null  float64
#  11  Y_ActualPosition          32048 non-null  float64
#  12  Y_ActualVelocity          32048 non-null  float64
#  13  Y_ActualAcceleration      32048 non-null  float64
#  14  Y_SetPosition             32048 non-null  float64
#  15  Y_SetVelocity             32048 non-null  float64
#  16  Y_SetAcceleration         32048 non-null  float64
#  17  Y_CurrentFeedback         32048 non-null  float64
#  18  Y_DCBusVoltage            32048 non-null  float64
#  19  Y_OutputCurrent           32048 non-null  int64
#  20  Y_OutputVoltage           32048 non-null  float64
#  21  Y_OutputPower             32048 non-null  float64
#  22  Z_ActualPosition          32048 non-null  float64
#  23  Z_ActualVelocity          32048 non-null  float64
#  24  Z_ActualAcceleration      32048 non-null  float64
#  25  Z_SetPosition             32048 non-null  float64
#  26  Z_SetVelocity             32048 non-null  float64
#  27  Z_SetAcceleration         32048 non-null  float64
#  28  Z_CurrentFeedback         32048 non-null  int64
#  29  Z_DCBusVoltage            32048 non-null  int64
#  30  Z_OutputCurrent           32048 non-null  int64
#  31  Z_OutputVoltage           32048 non-null  int64
#  32  S_ActualPosition          32048 non-null  float64
#  33  S_ActualVelocity          32048 non-null  float64
#  34  S_ActualAcceleration      32048 non-null  float64
#  35  S_SetPosition             32048 non-null  float64
#  36  S_SetVelocity             32048 non-null  float64
#  37  S_SetAcceleration         32048 non-null  float64
#  38  S_CurrentFeedback         32048 non-null  float64
#  39  S_DCBusVoltage            32048 non-null  float64
#  40  S_OutputCurrent           32048 non-null  int64
#  41  S_OutputVoltage           32048 non-null  float64
#  42  S_OutputPower             32048 non-null  float64
#  43  S_SystemInertia           32048 non-null  float64
#  44  M_CURRENT_PROGRAM_NUMBER  32048 non-null  int64
#  45  M_sequence_number         32048 non-null  int64
#  46  M_CURRENT_FEEDRATE        32048 non-null  int64
#  47  Machining_Process         32048 non-null  object
# dtypes: float64(37), int64(10), object(1)
# memory usage: 11.7+ MB
# None

# %%
print(df.describe())
# Out:
#        X_ActualPosition  X_ActualVelocity  X_ActualAcceleration  \
# count      32048.000000      32048.000000          32048.000000
# mean         163.805667          3.992182              4.455950
# std           18.461808          5.629767             91.780434
# min          144.000000        -17.300000          -1275.000000
# 25%          150.000000          2.330000            -26.300000
# 50%          158.000000          4.025000              4.000000
# 75%          167.000000          5.175000             30.000000
# max          203.000000         55.300000           1444.000000
#
#        X_SetPosition  X_SetVelocity  X_SetAcceleration  X_CurrentFeedback  \
# count   32048.000000   32048.000000       32048.000000       32048.000000
# mean      163.804013       3.997159           4.435959          -0.477972
# std        18.462444       5.634569          72.012521           4.230802
# min       144.000000     -17.000000        -997.000000         -23.400000
# 25%       150.000000       2.300000           3.000000          -3.860000
# 50%       158.000000       4.000000           5.000000          -0.619000
# 75%       167.000000       5.000000           5.000000           2.820000
# max       203.000000      55.000000        1005.000000          27.100000
#
#        X_DCBusVoltage  X_OutputCurrent  X_OutputVoltage  ...  \
# count    3.204800e+04     32048.000000     32048.000000  ...
# mean     6.421386e-02       326.894689         8.144473  ...
# std      3.994749e-02         1.493034         8.765644  ...
# min      2.780000e-19       320.000000         0.000000  ...
# 25%      3.200000e-02       326.000000         2.110000  ...
# 50%      6.410000e-02       327.000000         6.640000  ...
# 75%      9.130000e-02       327.000000        10.200000  ...
# max      3.800000e-01       331.000000        75.400000  ...
#
#        S_SetAcceleration  S_CurrentFeedback  S_DCBusVoltage  S_OutputCurrent  \
# count       32048.000000       32048.000000    3.204800e+04     32048.000000
# mean            4.662413          14.440084    6.347587e-01       322.990046
# std             5.983271          10.663567    4.525300e-01         4.420659
# min             2.999999          -8.280000    0.000000e+00       290.000000
# 25%             3.000001           0.555000    2.770000e-19       320.000000
# 50%             4.999999          18.400000    8.480000e-01       323.000000
# 75%             5.000000          22.200000    9.500000e-01       327.000000
# max           105.000000          75.400000    3.160000e+00       332.000000
#
#        S_OutputVoltage  S_OutputPower  S_SystemInertia  \
# count     32048.000000   32048.000000     32048.000000
# mean         80.669823       0.120718        16.275493
# std          54.714977       0.084254         0.876989
# min           0.000000      -0.002960        15.000000
# 25%           0.000000       0.000002        15.000000
# 50%         116.000000       0.162000        17.000000
# 75%         119.000000       0.183000        17.000000
# max         130.000000       0.569000        17.000000
#
#        M_CURRENT_PROGRAM_NUMBER  M_sequence_number  M_CURRENT_FEEDRATE
# count              32048.000000       32048.000000        32048.000000
# mean                   1.005429          44.457907           18.425237
# std                    0.438464          43.674509           20.007601
# min                    0.000000           0.000000            3.000000
# 25%                    1.000000           0.000000            3.000000
# 50%                    1.000000          34.000000            6.000000
# 75%                    1.000000          81.000000           50.000000
# max                    4.000000         135.000000           50.000000
#
# [8 rows x 47 columns]

# %% [markdown]
# #### 종속변수 별 샘플 수 세기
#
# - machining_finalized = 공정완료 유무<br>
# - passed_visual_inspection = 육안검사 통과유무

# %%
train_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   No                        25 non-null     int64
#  1   material                  25 non-null     object
#  2   feedrate                  25 non-null     int64
#  3   clamp_pressure            25 non-null     float64
#  4   tool_condition            25 non-null     object
#  5   machining_finalized       25 non-null     object
#  6   passed_visual_inspection  19 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.5+ KB

# %%
nb_pass = 0
nb_pass_half = 0
nb_defective = 0

train_sample_np = np.array(train_sample.copy())
for i in range(len(train_sample_np)):
    if train_sample_np[i, 5] == 'yes' and train_sample_np[i, 6] == 'yes':
        nb_pass += 1
    elif train_sample_np[i, 5] == 'yes' and train_sample_np[i, 6] == 'no':
        nb_pass_half += 1
    else:
        nb_defective += 1

print(f'공정 완료 및 육안검사 통과: {nb_pass}')
print(f'공정 완료되었으나 육안검사 불합격: {nb_pass_half}')
print(f'공정 미완료: {nb_defective}')
print(f'전체 샘플 개수: {nb_pass + nb_pass_half + nb_defective}')
# Out:
# 공정 완료 및 육안검사 통과: 13
# 공정 완료되었으나 육안검사 불합격: 6
# 공정 미완료: 6
# 전체 샘플 개수: 25

# %% [markdown]
# ### 2-3. 데이터 정제(전처리)

# %% [markdown]
# #### CNC 가공 실적 데이터 파일 전처리
# - tool_condition 함수: 입력값으로 불러온 ‘train.csv’ 파일을 받고, 출력값으로 각 샘플의 tool_condition에 대해 ‘마모되지않음(unworn)‘ 이면 (0)을, ’마모됨(worn)’ 이면 (1)
# - item_inspection 함수: 입력값으로 불러온 ‘train.csv’ 파일을 받고, 출력값으로 각 샘플의 machining_finalized(공정완료)와 passed_visual_inspection(육안검사) 두
# 가지 항목을 확인하고, 공정완료 및 육안검사 합격(0), 공정완료 및 육안검사 불합격(1), 공정미완료(2)의 3가지 값을 갖는다.

# %%
def tool_condition(df):
    df['tool_condition'] = df['tool_condition'].apply(lambda x: 0 if x == 'unworn' else 1)
    return df

def item_inspection(df):
    df['passed_visual_inspection'] = df.apply(
        lambda row: 
            0 if row['machining_finalized'] == 'yes' and row['passed_visual_inspection'] == 'yes'
                else 1 if row['machining_finalized'] == 'yes' and row['passed_visual_inspection'] == 'no'
                    else 2, axis=1)
    return df

# %%
train_sample_info = tool_condition(train_sample.copy())
train_sample_info = item_inspection(train_sample_info)
train_sample_info = train_sample_info.drop(columns=['No', 'material', 'machining_finalized'])
train_sample_info = np.array(train_sample_info)

# %%
train_sample_info
# Out:
# array([[ 6. ,  4. ,  0. ,  0. ],
#        [20. ,  4. ,  0. ,  0. ],
#        [ 6. ,  3. ,  0. ,  0. ],
#        [ 6. ,  2.5,  0. ,  2. ],
#        [20. ,  3. ,  0. ,  2. ],
#        [ 6. ,  4. ,  1. ,  1. ],
#        [20. ,  4. ,  1. ,  2. ],
#        [20. ,  4. ,  1. ,  1. ],
#        [15. ,  4. ,  1. ,  1. ],
#        [12. ,  4. ,  1. ,  1. ],
#        [ 3. ,  4. ,  0. ,  0. ],
#        [ 3. ,  3. ,  0. ,  0. ],
#        [ 3. ,  4. ,  1. ,  0. ],
#        [ 3. ,  3. ,  1. ,  0. ],
#        [ 6. ,  3. ,  1. ,  0. ],
#        [20. ,  3. ,  1. ,  2. ],
#        [ 3. ,  2.5,  0. ,  0. ],
#        [ 3. ,  2.5,  1. ,  0. ],
#        [15. ,  4. ,  1. ,  1. ],
#        [12. ,  4. ,  0. ,  2. ],
#        [ 3. ,  4. ,  0. ,  1. ],
#        [20. ,  3. ,  1. ,  0. ],
#        [ 3. ,  4. ,  1. ,  2. ],
#        [ 3. ,  3. ,  0. ,  0. ],
#        [ 6. ,  2.5,  1. ,  0. ]])

# %% [markdown]
# #### CNC 실적 및 개별 생산 단위 데이터 통합 후 공정 및 육안 검사 상태별 분할
# - data_pass : 공정 완료 및 육안검사 통과한 전체 데이터
# - data_pass_half : 공정 완료되었으나 육안검사 불합격한 전체 데이터
# - data_fail : 공정 미완료한 전체 데이터

# %%
k = 0
li_pass = []
li_pass_half = []
li_fail = []

for filename in all_files:
    file_df = pd.read_csv(filename, index_col=None, header=0)

    if train_sample_info[k, 3] == 0:
        li_pass.append(file_df)
    elif train_sample_info[k, 3] == 1:
        li_pass_half.append(file_df)
    else:
        li_fail.append(file_df)
    k+=1

data_pass = pd.concat(li_pass, axis=0, ignore_index=True)
data_pass_half = pd.concat(li_pass_half, axis=0, ignore_index=True)
data_fail = pd.concat(li_fail, axis=0, ignore_index=True)

print(f'공정 완료 및 육안검사 통과한 전체 데이터 수: {len(data_pass)}')
print(f'공정 완료되었으나 육안검사 불합격한 전체 데이터 수 : {len(data_pass_half)}')
print(f'공정 미완료한 전체 데이터 수 : {len(data_fail)}')
# Out:
# 공정 완료 및 육안검사 통과한 전체 데이터 수: 22645
# 공정 완료되었으나 육안검사 불합격한 전체 데이터 수 : 6175
# 공정 미완료한 전체 데이터 수 : 3228

# %% [markdown]
# #### 통합 데이터 전처리
# - machining_process 함수: 입력값으로 앞선 두 사용자 함수를 거친 통합 데이터를 받고, 기계의 공정상태(machining_process)를 숫자로 변환한다.

# %%
def machining_process(df):
    process_dict = {
        'Prep': 0, 'Layer 1 Up': 1, 'Layer 1 Down': 2, 'Layer 2 Up': 3,
        'Layer 2 Down': 4, 'Layer 3 Up': 5, 'Layer 3 Down': 6,
        'Repositioning': 7, 'End': 8,  'end': 8, 'Starting': 9
    }
    df['Machining_Process'] = df['Machining_Process'].map(process_dict)
    return df

# %%
data_pass = machining_process(data_pass)
data_pass_half = machining_process(data_pass_half)
data_fail = machining_process(data_fail)

# %%
data_pass['Machining_Process'].value_counts()
# Out:
# Machining_Process
# 1    3578
# 7    3299
# 3    2726
# 5    2715
# 2    2516
# 4    2272
# 6    2144
# 8    1740
# 0    1654
# 9       1
# Name: count, dtype: int64

# %% [markdown]
# #### 데이터 라벨링
# - 1: 양품
# - 0: 불량품

# %%
data_pass['Label'] = 1
data_pass_half['Label'] = 0
data_fail['Label'] = 0

# %% [markdown]
# #### 훈련/테스트 데이터 분리

# %%
data_pass = np.array(data_pass)
data_pass_half = np.array(data_pass_half)
data_fail = np.array(data_fail)

# %%
def split_data(data):
    X = data[:, :-1]
    y = data[:, -1:]
    return train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train_pass, X_test_pass, y_train_pass, y_test_pass = split_data(data_pass)
X_train_pass_half, X_test_pass_half, y_train_pass_half, y_test_pass_half = split_data(data_pass_half)
X_train_fail, X_test_fail, y_train_fail, y_test_fail = split_data(data_fail)

# %%
X_train = np.concatenate((X_train_pass, X_train_pass_half, X_train_fail), axis=0)
y_train = np.concatenate((y_train_pass, y_train_pass_half, y_train_fail), axis=0)
X_test = np.concatenate((X_test_pass, X_test_pass_half, X_test_fail), axis=0)
y_test = np.concatenate((y_test_pass, y_test_pass_half, y_test_fail), axis=0)

# %%
X_train.shape
# Out:
# (22432, 48)

# %%
X_test.shape
# Out:
# (9616, 48)

# %% [markdown]
# #### 정규화
#
# Min-max normalization는 데이터를 0과 1 사이의 값으로 scaling합니다.
#
# 1) data의 최대값(max)과 최소값(min)을 구한다.
# 2) 정규화할 데이터 값(x)과 앞서 구한 최대값(Xmax), 최소값(Xmin)을 다음의 식에 대입한다.<br>
#
# <img src="https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/c5a29097-0eb4-44a5-b379-2ea9df771095" width="400" height="400"/>

# %%
# 데이터 정규화
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[0.20338983, 0.31859504, 0.45089955, ..., 0.9037037 , 0.        ,
#         0.125     ],
#        [0.10169492, 0.23787879, 0.47432534, ..., 0.1037037 , 0.        ,
#         0.375     ],
#        [0.06779661, 0.27658402, 0.48212144, ..., 0.64444444, 0.        ,
#         0.625     ],
#        ...,
#        [0.15254237, 0.03168044, 0.45633433, ..., 0.47407407, 0.36170213,
#         0.25      ],
#        [0.96610169, 0.27926997, 0.45792729, ..., 0.        , 0.06382979,
#         1.        ],
#        [0.34745763, 0.25344353, 0.47118628, ..., 0.05185185, 1.        ,
#         1.        ]])

# %% [markdown]
# ### 2-4. 모델 구축 및 훈련

# %% [markdown]
# **심층 신경망(DNN)**
# - 심층 신경망(Deep Neural Network)은 여러 층의 노드로 구성된 신경망 구조를 쌓아 학습시키는 AI 알고리즘입니다.
#
#     |<b>DNN의 기본구조</b> |
#     | :--: |
#     | ![](https://parallelr.com/uploads/2016/02/dnn_architecture.png)|
#     | (출처:https://parallelr.com/2016/02/13/r-deep-neural-network-from-scratch/)|
#
#
# - 각 노드는 입력 데이터를 받아 연산 후 결과를 출력하며, 활성화 함수(예: 시그모이드, ReLU)를 통해 비선형 변환을 수행합니다.
#
#     |<b>활성화 함수 예: ReLU, sigmoid</b> |
#     | :--: |
#     | ![CNC_5](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/19863edd-d7a5-4d73-8462-cd238e520c82)|
#
# - 학습은 경사 하강법을 통해 손실함수(loss function)를 최소화하는 방향으로 진행되며, 분류 문제에서는 주로 이진 교차 엔트로피(binary crossentropy)를 사용합니다.
#
#     |<b>이진 교차 엔트로피(binary crossentropy)</b> |
#     | :--: |
#     | ![CNC_6](https://github.com/YoungsukHan/Hyundai_equip/assets/44924554/e73cdb2d-da9f-49e9-a414-d364a87bff2c)|

# %% [markdown]
# ### DNN 모델 구축

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# AI 모델 파라미터 설정
batch_size = 1024
epochs = 300

# AI 모델 디자인
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 모델 요약
model.summary()
# Out:
# C:\Users\Han\Miniconda3\envs\hyundai_equip_6\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 64)                  │           3,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,361 (28.75 KB)
#  Trainable params: 7,361 (28.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 모델 학습

# %%
# 모델 훈련
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1, shuffle=True)
# Out:
# Epoch 1/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7853 - loss: 0.5292 - val_accuracy: 0.0000e+00 - val_loss: 1.4115
# Epoch 2/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7833 - loss: 0.4688 - val_accuracy: 0.0192 - val_loss: 1.1440
# Epoch 3/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7869 - loss: 0.4443 - val_accuracy: 0.0686 - val_loss: 1.1294
# Epoch 4/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8062 - loss: 0.4117 - val_accuracy: 0.1408 - val_loss: 1.0986
# Epoch 5/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8160 - loss: 0.3801 - val_accuracy: 0.2799 - val_loss: 1.0537
# Epoch 6/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8374 - loss: 0.3447 - val_accuracy: 0.3160 - val_loss: 1.1650
# Epoch 7/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8489 - loss: 0.3121 - val_accuracy: 0.3592 - val_loss: 1.1228
# Epoch 8/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8543 - loss: 0.2939 - val_accuracy: 0.3636 - val_loss: 1.1679
# Epoch 9/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8615 - loss: 0.2792 - val_accuracy: 0.3676 - val_loss: 1.2229
# Epoch 10/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8684 - loss: 0.2611 - val_accuracy: 0.4176 - val_loss: 1.1064
# Epoch 11/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8778 - loss: 0.2455 - val_accuracy: 0.4225 - val_loss: 1.1451
# Epoch 12/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8820 - loss: 0.2312 - val_accuracy: 0.4247 - val_loss: 1.0969
# Epoch 13/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8802 - loss: 0.2279 - val_accuracy: 0.4109 - val_loss: 1.2197
# Epoch 14/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8939 - loss: 0.2102 - val_accuracy: 0.4118 - val_loss: 1.2434
# Epoch 15/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8985 - loss: 0.1993 - val_accuracy: 0.4474 - val_loss: 1.1515
# Epoch 16/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9020 - loss: 0.1922 - val_accuracy: 0.4394 - val_loss: 1.1837
# Epoch 17/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9118 - loss: 0.1792 - val_accuracy: 0.4425 - val_loss: 1.1568
# Epoch 18/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9174 - loss: 0.1698 - val_accuracy: 0.4265 - val_loss: 1.2970
# Epoch 19/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9226 - loss: 0.1602 - val_accuracy: 0.5178 - val_loss: 1.1512
# Epoch 20/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9313 - loss: 0.1520 - val_accuracy: 0.5223 - val_loss: 1.2115
# Epoch 21/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.1510 - val_accuracy: 0.5205 - val_loss: 1.2294
# Epoch 22/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9382 - loss: 0.1449 - val_accuracy: 0.5272 - val_loss: 1.2256
# Epoch 23/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9422 - loss: 0.1404 - val_accuracy: 0.5178 - val_loss: 1.3554
# Epoch 24/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9432 - loss: 0.1362 - val_accuracy: 0.5307 - val_loss: 1.2970
# Epoch 25/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9498 - loss: 0.1292 - val_accuracy: 0.5512 - val_loss: 1.1670
# Epoch 26/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9551 - loss: 0.1218 - val_accuracy: 0.5245 - val_loss: 1.3947
# Epoch 27/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9552 - loss: 0.1208 - val_accuracy: 0.4906 - val_loss: 1.5243
# Epoch 28/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9572 - loss: 0.1168 - val_accuracy: 0.5339 - val_loss: 1.3229
# Epoch 29/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9582 - loss: 0.1137 - val_accuracy: 0.4893 - val_loss: 1.6497
# Epoch 30/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9580 - loss: 0.1123 - val_accuracy: 0.5437 - val_loss: 1.3314
# Epoch 31/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9608 - loss: 0.1073 - val_accuracy: 0.5619 - val_loss: 1.2819
# Epoch 32/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9598 - loss: 0.1051 - val_accuracy: 0.5223 - val_loss: 1.5955
# Epoch 33/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9599 - loss: 0.1043 - val_accuracy: 0.5392 - val_loss: 1.4431
# Epoch 34/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.1001 - val_accuracy: 0.5205 - val_loss: 1.5743
# Epoch 35/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9606 - loss: 0.1004 - val_accuracy: 0.5267 - val_loss: 1.5751
# Epoch 36/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.0958 - val_accuracy: 0.5049 - val_loss: 1.7175
# Epoch 37/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9647 - loss: 0.0940 - val_accuracy: 0.5227 - val_loss: 1.5800
# Epoch 38/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9646 - loss: 0.0933 - val_accuracy: 0.5094 - val_loss: 1.6978
# Epoch 39/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.0936 - val_accuracy: 0.4955 - val_loss: 1.8789
# Epoch 40/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.0883 - val_accuracy: 0.5258 - val_loss: 1.6731
# Epoch 41/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.0873 - val_accuracy: 0.5201 - val_loss: 1.6254
# Epoch 42/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.0897 - val_accuracy: 0.5254 - val_loss: 1.6330
# Epoch 43/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.0875 - val_accuracy: 0.5218 - val_loss: 1.7342
# Epoch 44/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9659 - loss: 0.0864 - val_accuracy: 0.5125 - val_loss: 1.7169
# Epoch 45/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.0847 - val_accuracy: 0.5455 - val_loss: 1.6240
# Epoch 46/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9682 - loss: 0.0823 - val_accuracy: 0.5419 - val_loss: 1.6280
# Epoch 47/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.0844 - val_accuracy: 0.5000 - val_loss: 1.9150
# Epoch 48/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9674 - loss: 0.0820 - val_accuracy: 0.5285 - val_loss: 1.8482
# Epoch 49/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9679 - loss: 0.0790 - val_accuracy: 0.5414 - val_loss: 1.6602
# Epoch 50/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9690 - loss: 0.0762 - val_accuracy: 0.5254 - val_loss: 1.7962
# Epoch 51/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9685 - loss: 0.0787 - val_accuracy: 0.5272 - val_loss: 1.7535
# Epoch 52/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9691 - loss: 0.0770 - val_accuracy: 0.4964 - val_loss: 2.0283
# Epoch 53/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9679 - loss: 0.0774 - val_accuracy: 0.5486 - val_loss: 1.7825
# Epoch 54/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9652 - loss: 0.0819 - val_accuracy: 0.5526 - val_loss: 1.6575
# Epoch 55/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9695 - loss: 0.0739 - val_accuracy: 0.5094 - val_loss: 2.0161
# Epoch 56/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.0745 - val_accuracy: 0.5307 - val_loss: 1.8873
# Epoch 57/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9715 - loss: 0.0714 - val_accuracy: 0.5307 - val_loss: 1.8304
# Epoch 58/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9700 - loss: 0.0728 - val_accuracy: 0.5196 - val_loss: 2.0452
# Epoch 59/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9694 - loss: 0.0740 - val_accuracy: 0.5111 - val_loss: 2.0623
# Epoch 60/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9691 - loss: 0.0724 - val_accuracy: 0.5267 - val_loss: 1.9259
# Epoch 61/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9699 - loss: 0.0700 - val_accuracy: 0.5388 - val_loss: 1.9980
# Epoch 62/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9717 - loss: 0.0669 - val_accuracy: 0.5294 - val_loss: 2.0464
# Epoch 63/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9709 - loss: 0.0678 - val_accuracy: 0.5183 - val_loss: 2.0171
# Epoch 64/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9703 - loss: 0.0696 - val_accuracy: 0.5263 - val_loss: 2.0120
# Epoch 65/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9710 - loss: 0.0680 - val_accuracy: 0.5267 - val_loss: 2.1730
# Epoch 66/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.0692 - val_accuracy: 0.5232 - val_loss: 2.2083
# Epoch 67/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9707 - loss: 0.0708 - val_accuracy: 0.5120 - val_loss: 2.2358
# Epoch 68/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9725 - loss: 0.0665 - val_accuracy: 0.5254 - val_loss: 2.2559
# Epoch 69/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.0697 - val_accuracy: 0.5290 - val_loss: 2.0106
# Epoch 70/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.0682 - val_accuracy: 0.5499 - val_loss: 1.8699
# Epoch 71/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9706 - loss: 0.0683 - val_accuracy: 0.5250 - val_loss: 2.0739
# Epoch 72/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9729 - loss: 0.0635 - val_accuracy: 0.5352 - val_loss: 2.0926
# Epoch 73/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9719 - loss: 0.0681 - val_accuracy: 0.5102 - val_loss: 2.3315
# Epoch 74/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9736 - loss: 0.0644 - val_accuracy: 0.4991 - val_loss: 2.6249
# Epoch 75/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.0689 - val_accuracy: 0.5307 - val_loss: 2.3214
# Epoch 76/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9702 - loss: 0.0659 - val_accuracy: 0.5414 - val_loss: 2.1758
# Epoch 77/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9715 - loss: 0.0656 - val_accuracy: 0.5165 - val_loss: 2.4914
# Epoch 78/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9720 - loss: 0.0657 - val_accuracy: 0.5455 - val_loss: 2.0274
# Epoch 79/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9716 - loss: 0.0641 - val_accuracy: 0.5254 - val_loss: 2.4123
# Epoch 80/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9708 - loss: 0.0654 - val_accuracy: 0.5192 - val_loss: 2.3300
# Epoch 81/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9727 - loss: 0.0648 - val_accuracy: 0.5245 - val_loss: 2.2957
# Epoch 82/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9720 - loss: 0.0638 - val_accuracy: 0.5361 - val_loss: 2.0833
# Epoch 83/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9736 - loss: 0.0637 - val_accuracy: 0.5348 - val_loss: 2.3030
# Epoch 84/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9736 - loss: 0.0609 - val_accuracy: 0.5285 - val_loss: 2.2568
# Epoch 85/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9733 - loss: 0.0627 - val_accuracy: 0.5397 - val_loss: 2.2029
# Epoch 86/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9732 - loss: 0.0614 - val_accuracy: 0.5334 - val_loss: 2.3815
# Epoch 87/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9709 - loss: 0.0632 - val_accuracy: 0.5205 - val_loss: 2.2526
# Epoch 88/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.0575 - val_accuracy: 0.5192 - val_loss: 2.4919
# Epoch 89/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9731 - loss: 0.0614 - val_accuracy: 0.5250 - val_loss: 2.2528
# Epoch 90/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9732 - loss: 0.0624 - val_accuracy: 0.5299 - val_loss: 2.4273
# Epoch 91/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9736 - loss: 0.0619 - val_accuracy: 0.5236 - val_loss: 2.3133
# Epoch 92/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9742 - loss: 0.0603 - val_accuracy: 0.5740 - val_loss: 2.1526
# Epoch 93/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9724 - loss: 0.0589 - val_accuracy: 0.5303 - val_loss: 2.6966
# Epoch 94/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9716 - loss: 0.0616 - val_accuracy: 0.5241 - val_loss: 2.3092
# Epoch 95/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9751 - loss: 0.0592 - val_accuracy: 0.5258 - val_loss: 2.6650
# Epoch 96/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9731 - loss: 0.0586 - val_accuracy: 0.5254 - val_loss: 2.3179
# Epoch 97/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9744 - loss: 0.0581 - val_accuracy: 0.5459 - val_loss: 2.4034
# Epoch 98/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9712 - loss: 0.0596 - val_accuracy: 0.5183 - val_loss: 2.7061
# Epoch 99/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.0569 - val_accuracy: 0.5245 - val_loss: 2.4957
# Epoch 100/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.0556 - val_accuracy: 0.5419 - val_loss: 2.7315
# Epoch 101/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9745 - loss: 0.0559 - val_accuracy: 0.5263 - val_loss: 2.6335
# Epoch 102/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9769 - loss: 0.0554 - val_accuracy: 0.5227 - val_loss: 2.5435
# Epoch 103/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9760 - loss: 0.0561 - val_accuracy: 0.5254 - val_loss: 2.6733
# Epoch 104/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.0585 - val_accuracy: 0.5374 - val_loss: 2.4495
# Epoch 105/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9740 - loss: 0.0585 - val_accuracy: 0.5174 - val_loss: 2.5964
# Epoch 106/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9773 - loss: 0.0535 - val_accuracy: 0.5383 - val_loss: 2.7457
# Epoch 107/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9724 - loss: 0.0597 - val_accuracy: 0.5370 - val_loss: 2.3394
# Epoch 108/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9751 - loss: 0.0579 - val_accuracy: 0.5914 - val_loss: 2.2335
# Epoch 109/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9734 - loss: 0.0602 - val_accuracy: 0.5414 - val_loss: 2.4373
# Epoch 110/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9754 - loss: 0.0564 - val_accuracy: 0.5526 - val_loss: 2.4313
# Epoch 111/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9732 - loss: 0.0577 - val_accuracy: 0.5254 - val_loss: 2.5516
# Epoch 112/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.0558 - val_accuracy: 0.5566 - val_loss: 2.5557
# Epoch 113/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9748 - loss: 0.0555 - val_accuracy: 0.5174 - val_loss: 2.8611
# Epoch 114/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9759 - loss: 0.0548 - val_accuracy: 0.5468 - val_loss: 2.4570
# Epoch 115/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9757 - loss: 0.0545 - val_accuracy: 0.5334 - val_loss: 2.8107
# Epoch 116/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.0556 - val_accuracy: 0.5276 - val_loss: 2.7690
# Epoch 117/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9747 - loss: 0.0527 - val_accuracy: 0.5236 - val_loss: 2.7262
# Epoch 118/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9765 - loss: 0.0530 - val_accuracy: 0.5339 - val_loss: 2.6588
# Epoch 119/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.0542 - val_accuracy: 0.5379 - val_loss: 2.7023
# Epoch 120/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9745 - loss: 0.0556 - val_accuracy: 0.5579 - val_loss: 2.5344
# Epoch 121/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9749 - loss: 0.0557 - val_accuracy: 0.5717 - val_loss: 2.5214
# Epoch 122/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9753 - loss: 0.0550 - val_accuracy: 0.5512 - val_loss: 2.6417
# Epoch 123/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9768 - loss: 0.0527 - val_accuracy: 0.5486 - val_loss: 2.6706
# Epoch 124/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9753 - loss: 0.0526 - val_accuracy: 0.5530 - val_loss: 2.6275
# Epoch 125/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9769 - loss: 0.0506 - val_accuracy: 0.5646 - val_loss: 2.6206
# Epoch 126/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9748 - loss: 0.0528 - val_accuracy: 0.5651 - val_loss: 2.4281
# Epoch 127/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9739 - loss: 0.0551 - val_accuracy: 0.5174 - val_loss: 2.9894
# Epoch 128/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.0529 - val_accuracy: 0.5339 - val_loss: 2.9799
# Epoch 129/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9751 - loss: 0.0538 - val_accuracy: 0.5535 - val_loss: 2.7904
# Epoch 130/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9769 - loss: 0.0501 - val_accuracy: 0.5499 - val_loss: 2.6552
# Epoch 131/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9785 - loss: 0.0482 - val_accuracy: 0.5419 - val_loss: 2.8090
# Epoch 132/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9774 - loss: 0.0503 - val_accuracy: 0.5588 - val_loss: 2.7530
# Epoch 133/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9760 - loss: 0.0519 - val_accuracy: 0.5236 - val_loss: 3.0319
# Epoch 134/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9769 - loss: 0.0516 - val_accuracy: 0.5361 - val_loss: 2.8193
# Epoch 135/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9766 - loss: 0.0525 - val_accuracy: 0.5276 - val_loss: 2.9759
# Epoch 136/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9759 - loss: 0.0533 - val_accuracy: 0.5214 - val_loss: 2.8631
# Epoch 137/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9763 - loss: 0.0506 - val_accuracy: 0.5566 - val_loss: 2.8730
# Epoch 138/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9777 - loss: 0.0481 - val_accuracy: 0.5272 - val_loss: 2.9723
# Epoch 139/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9786 - loss: 0.0481 - val_accuracy: 0.5548 - val_loss: 2.5314
# Epoch 140/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9766 - loss: 0.0512 - val_accuracy: 0.5379 - val_loss: 2.9560
# Epoch 141/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9767 - loss: 0.0508 - val_accuracy: 0.5740 - val_loss: 2.5914
# Epoch 142/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0484 - val_accuracy: 0.5798 - val_loss: 2.4184
# Epoch 143/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9777 - loss: 0.0489 - val_accuracy: 0.5441 - val_loss: 2.9145
# Epoch 144/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9791 - loss: 0.0464 - val_accuracy: 0.5566 - val_loss: 2.7385
# Epoch 145/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9772 - loss: 0.0487 - val_accuracy: 0.5299 - val_loss: 3.1458
# Epoch 146/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9768 - loss: 0.0499 - val_accuracy: 0.5539 - val_loss: 2.7449
# Epoch 147/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9777 - loss: 0.0481 - val_accuracy: 0.5811 - val_loss: 2.7299
# Epoch 148/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.0482 - val_accuracy: 0.5419 - val_loss: 2.9495
# Epoch 149/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9762 - loss: 0.0501 - val_accuracy: 0.5401 - val_loss: 3.0647
# Epoch 150/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9773 - loss: 0.0499 - val_accuracy: 0.5267 - val_loss: 3.1083
# Epoch 151/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9783 - loss: 0.0481 - val_accuracy: 0.5633 - val_loss: 2.8346
# Epoch 152/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0502 - val_accuracy: 0.5570 - val_loss: 2.8669
# Epoch 153/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9790 - loss: 0.0466 - val_accuracy: 0.5325 - val_loss: 3.0183
# Epoch 154/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9782 - loss: 0.0477 - val_accuracy: 0.5633 - val_loss: 2.9082
# Epoch 155/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9768 - loss: 0.0491 - val_accuracy: 0.5285 - val_loss: 3.0538
# Epoch 156/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9769 - loss: 0.0502 - val_accuracy: 0.5410 - val_loss: 3.0072
# Epoch 157/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9782 - loss: 0.0484 - val_accuracy: 0.5793 - val_loss: 2.5571
# Epoch 158/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9788 - loss: 0.0466 - val_accuracy: 0.5423 - val_loss: 3.0563
# Epoch 159/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9769 - loss: 0.0495 - val_accuracy: 0.5321 - val_loss: 3.1042
# Epoch 160/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9788 - loss: 0.0484 - val_accuracy: 0.5325 - val_loss: 3.0346
# Epoch 161/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0487 - val_accuracy: 0.5539 - val_loss: 2.8888
# Epoch 162/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9794 - loss: 0.0453 - val_accuracy: 0.5619 - val_loss: 3.0805
# Epoch 163/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0488 - val_accuracy: 0.5726 - val_loss: 3.0515
# Epoch 164/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9786 - loss: 0.0463 - val_accuracy: 0.5490 - val_loss: 2.8859
# Epoch 165/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9779 - loss: 0.0460 - val_accuracy: 0.5183 - val_loss: 3.4481
# Epoch 166/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0477 - val_accuracy: 0.5379 - val_loss: 3.1508
# Epoch 167/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9791 - loss: 0.0456 - val_accuracy: 0.5330 - val_loss: 3.2057
# Epoch 168/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9779 - loss: 0.0468 - val_accuracy: 0.5726 - val_loss: 2.7338
# Epoch 169/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9776 - loss: 0.0472 - val_accuracy: 0.5673 - val_loss: 2.7776
# Epoch 170/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9772 - loss: 0.0485 - val_accuracy: 0.5905 - val_loss: 2.3689
# Epoch 171/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9760 - loss: 0.0504 - val_accuracy: 0.5628 - val_loss: 3.0179
# Epoch 172/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0472 - val_accuracy: 0.5704 - val_loss: 3.0576
# Epoch 173/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9782 - loss: 0.0460 - val_accuracy: 0.5557 - val_loss: 3.1239
# Epoch 174/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9797 - loss: 0.0437 - val_accuracy: 0.5798 - val_loss: 2.9919
# Epoch 175/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0457 - val_accuracy: 0.5740 - val_loss: 3.0093
# Epoch 176/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9790 - loss: 0.0453 - val_accuracy: 0.5677 - val_loss: 2.6613
# Epoch 177/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9784 - loss: 0.0460 - val_accuracy: 0.5726 - val_loss: 2.6735
# Epoch 178/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9763 - loss: 0.0472 - val_accuracy: 0.5432 - val_loss: 3.0936
# Epoch 179/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9790 - loss: 0.0456 - val_accuracy: 0.5352 - val_loss: 3.2733
# Epoch 180/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9793 - loss: 0.0439 - val_accuracy: 0.5668 - val_loss: 2.9594
# Epoch 181/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9793 - loss: 0.0447 - val_accuracy: 0.5686 - val_loss: 2.9670
# Epoch 182/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9774 - loss: 0.0477 - val_accuracy: 0.5624 - val_loss: 3.2699
# Epoch 183/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9786 - loss: 0.0439 - val_accuracy: 0.5361 - val_loss: 3.4273
# Epoch 184/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0449 - val_accuracy: 0.5472 - val_loss: 3.1463
# Epoch 185/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9781 - loss: 0.0447 - val_accuracy: 0.5860 - val_loss: 2.7009
# Epoch 186/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9782 - loss: 0.0455 - val_accuracy: 0.5664 - val_loss: 3.0965
# Epoch 187/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9804 - loss: 0.0426 - val_accuracy: 0.5423 - val_loss: 3.3805
# Epoch 188/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9783 - loss: 0.0457 - val_accuracy: 0.5254 - val_loss: 3.5250
# Epoch 189/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9785 - loss: 0.0461 - val_accuracy: 0.5722 - val_loss: 3.1001
# Epoch 190/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.0442 - val_accuracy: 0.5414 - val_loss: 3.4287
# Epoch 191/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0438 - val_accuracy: 0.5588 - val_loss: 3.1000
# Epoch 192/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9784 - loss: 0.0455 - val_accuracy: 0.5735 - val_loss: 3.0197
# Epoch 193/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9781 - loss: 0.0458 - val_accuracy: 0.5749 - val_loss: 2.8539
# Epoch 194/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9809 - loss: 0.0428 - val_accuracy: 0.5713 - val_loss: 3.1598
# Epoch 195/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9794 - loss: 0.0422 - val_accuracy: 0.5307 - val_loss: 3.5332
# Epoch 196/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.0431 - val_accuracy: 0.5740 - val_loss: 3.1747
# Epoch 197/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0440 - val_accuracy: 0.5530 - val_loss: 3.3513
# Epoch 198/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9803 - loss: 0.0424 - val_accuracy: 0.5682 - val_loss: 3.1144
# Epoch 199/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9781 - loss: 0.0441 - val_accuracy: 0.5660 - val_loss: 3.2317
# Epoch 200/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9800 - loss: 0.0436 - val_accuracy: 0.5619 - val_loss: 3.2694
# Epoch 201/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.0440 - val_accuracy: 0.5218 - val_loss: 3.7209
# Epoch 202/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9784 - loss: 0.0469 - val_accuracy: 0.5490 - val_loss: 3.4343
# Epoch 203/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0430 - val_accuracy: 0.5432 - val_loss: 3.4395
# Epoch 204/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9805 - loss: 0.0426 - val_accuracy: 0.5646 - val_loss: 3.4325
# Epoch 205/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9794 - loss: 0.0435 - val_accuracy: 0.5450 - val_loss: 3.4606
# Epoch 206/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9805 - loss: 0.0419 - val_accuracy: 0.5717 - val_loss: 3.3805
# Epoch 207/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.0450 - val_accuracy: 0.5824 - val_loss: 2.6646
# Epoch 208/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9788 - loss: 0.0437 - val_accuracy: 0.5820 - val_loss: 3.1814
# Epoch 209/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9816 - loss: 0.0398 - val_accuracy: 0.5722 - val_loss: 3.1614
# Epoch 210/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0432 - val_accuracy: 0.5633 - val_loss: 3.0707
# Epoch 211/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9803 - loss: 0.0442 - val_accuracy: 0.5744 - val_loss: 3.2986
# Epoch 212/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9785 - loss: 0.0444 - val_accuracy: 0.5646 - val_loss: 2.8242
# Epoch 213/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9787 - loss: 0.0440 - val_accuracy: 0.5735 - val_loss: 3.3468
# Epoch 214/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9790 - loss: 0.0421 - val_accuracy: 0.5784 - val_loss: 3.0936
# Epoch 215/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0440 - val_accuracy: 0.5998 - val_loss: 2.9862
# Epoch 216/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0423 - val_accuracy: 0.5753 - val_loss: 2.6624
# Epoch 217/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.0442 - val_accuracy: 0.5651 - val_loss: 3.2820
# Epoch 218/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0431 - val_accuracy: 0.5820 - val_loss: 3.3796
# Epoch 219/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0421 - val_accuracy: 0.5446 - val_loss: 3.9962
# Epoch 220/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9777 - loss: 0.0458 - val_accuracy: 0.5504 - val_loss: 3.4371
# Epoch 221/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0440 - val_accuracy: 0.5397 - val_loss: 3.9058
# Epoch 222/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9801 - loss: 0.0416 - val_accuracy: 0.5267 - val_loss: 3.7383
# Epoch 223/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9783 - loss: 0.0459 - val_accuracy: 0.5700 - val_loss: 3.7706
# Epoch 224/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9795 - loss: 0.0418 - val_accuracy: 0.5642 - val_loss: 3.6870
# Epoch 225/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.0432 - val_accuracy: 0.5798 - val_loss: 3.3561
# Epoch 226/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9803 - loss: 0.0407 - val_accuracy: 0.5811 - val_loss: 3.0658
# Epoch 227/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9774 - loss: 0.0467 - val_accuracy: 0.5735 - val_loss: 3.0814
# Epoch 228/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9807 - loss: 0.0400 - val_accuracy: 0.5490 - val_loss: 3.8850
# Epoch 229/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9805 - loss: 0.0413 - val_accuracy: 0.5713 - val_loss: 3.2008
# Epoch 230/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9801 - loss: 0.0427 - val_accuracy: 0.5744 - val_loss: 3.5694
# Epoch 231/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0434 - val_accuracy: 0.5771 - val_loss: 3.1460
# Epoch 232/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.0434 - val_accuracy: 0.5575 - val_loss: 2.9635
# Epoch 233/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0432 - val_accuracy: 0.5486 - val_loss: 3.8525
# Epoch 234/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9790 - loss: 0.0435 - val_accuracy: 0.5717 - val_loss: 3.3703
# Epoch 235/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9788 - loss: 0.0423 - val_accuracy: 0.5655 - val_loss: 3.5037
# Epoch 236/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0424 - val_accuracy: 0.5766 - val_loss: 3.5498
# Epoch 237/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9798 - loss: 0.0416 - val_accuracy: 0.5646 - val_loss: 3.7327
# Epoch 238/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9795 - loss: 0.0408 - val_accuracy: 0.5606 - val_loss: 3.8186
# Epoch 239/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.0405 - val_accuracy: 0.5615 - val_loss: 3.6477
# Epoch 240/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9807 - loss: 0.0406 - val_accuracy: 0.5673 - val_loss: 3.6820
# Epoch 241/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9809 - loss: 0.0400 - val_accuracy: 0.5726 - val_loss: 3.6804
# Epoch 242/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0407 - val_accuracy: 0.5660 - val_loss: 3.3906
# Epoch 243/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9782 - loss: 0.0440 - val_accuracy: 0.5735 - val_loss: 3.6160
# Epoch 244/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9806 - loss: 0.0399 - val_accuracy: 0.5887 - val_loss: 3.1992
# Epoch 245/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9801 - loss: 0.0419 - val_accuracy: 0.5713 - val_loss: 3.4449
# Epoch 246/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0409 - val_accuracy: 0.5709 - val_loss: 3.4334
# Epoch 247/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.0402 - val_accuracy: 0.5838 - val_loss: 3.4757
# Epoch 248/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.0401 - val_accuracy: 0.5655 - val_loss: 3.2202
# Epoch 249/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0403 - val_accuracy: 0.5227 - val_loss: 4.1169
# Epoch 250/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9790 - loss: 0.0430 - val_accuracy: 0.5695 - val_loss: 3.5622
# Epoch 251/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9796 - loss: 0.0417 - val_accuracy: 0.5664 - val_loss: 3.3296
# Epoch 252/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9804 - loss: 0.0408 - val_accuracy: 0.5673 - val_loss: 3.8944
# Epoch 253/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0397 - val_accuracy: 0.5584 - val_loss: 4.0229
# Epoch 254/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9794 - loss: 0.0411 - val_accuracy: 0.5316 - val_loss: 4.0980
# Epoch 255/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9804 - loss: 0.0392 - val_accuracy: 0.5223 - val_loss: 4.1630
# Epoch 256/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9817 - loss: 0.0386 - val_accuracy: 0.5548 - val_loss: 3.9912
# Epoch 257/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9807 - loss: 0.0400 - val_accuracy: 0.5664 - val_loss: 3.6247
# Epoch 258/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0406 - val_accuracy: 0.5842 - val_loss: 3.5570
# Epoch 259/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9808 - loss: 0.0392 - val_accuracy: 0.5446 - val_loss: 4.0367
# Epoch 260/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9800 - loss: 0.0407 - val_accuracy: 0.5593 - val_loss: 3.9288
# Epoch 261/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0395 - val_accuracy: 0.5686 - val_loss: 3.7034
# Epoch 262/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0410 - val_accuracy: 0.5798 - val_loss: 3.3919
# Epoch 263/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9796 - loss: 0.0404 - val_accuracy: 0.5419 - val_loss: 3.9285
# Epoch 264/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0407 - val_accuracy: 0.5619 - val_loss: 3.6069
# Epoch 265/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9809 - loss: 0.0400 - val_accuracy: 0.5250 - val_loss: 4.3387
# Epoch 266/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0417 - val_accuracy: 0.5468 - val_loss: 4.0160
# Epoch 267/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.0416 - val_accuracy: 0.5758 - val_loss: 3.7410
# Epoch 268/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9813 - loss: 0.0400 - val_accuracy: 0.5936 - val_loss: 3.5038
# Epoch 269/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.0414 - val_accuracy: 0.5686 - val_loss: 4.0214
# Epoch 270/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0397 - val_accuracy: 0.5704 - val_loss: 3.7017
# Epoch 271/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9803 - loss: 0.0394 - val_accuracy: 0.5646 - val_loss: 3.7675
# Epoch 272/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9810 - loss: 0.0386 - val_accuracy: 0.5775 - val_loss: 3.4453
# Epoch 273/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0404 - val_accuracy: 0.5615 - val_loss: 4.0721
# Epoch 274/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9803 - loss: 0.0387 - val_accuracy: 0.5619 - val_loss: 3.4681
# Epoch 275/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0410 - val_accuracy: 0.5740 - val_loss: 3.9153
# Epoch 276/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9808 - loss: 0.0396 - val_accuracy: 0.5713 - val_loss: 3.7271
# Epoch 277/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9804 - loss: 0.0393 - val_accuracy: 0.5660 - val_loss: 3.7638
# Epoch 278/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9799 - loss: 0.0399 - val_accuracy: 0.5677 - val_loss: 3.9919
# Epoch 279/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9788 - loss: 0.0413 - val_accuracy: 0.6029 - val_loss: 3.5084
# Epoch 280/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9803 - loss: 0.0432 - val_accuracy: 0.5851 - val_loss: 3.0298
# Epoch 281/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9795 - loss: 0.0409 - val_accuracy: 0.5820 - val_loss: 3.5620
# Epoch 282/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9794 - loss: 0.0400 - val_accuracy: 0.5677 - val_loss: 4.1136
# Epoch 283/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9809 - loss: 0.0387 - val_accuracy: 0.5593 - val_loss: 3.9799
# Epoch 284/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9805 - loss: 0.0380 - val_accuracy: 0.5655 - val_loss: 3.7345
# Epoch 285/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9812 - loss: 0.0391 - val_accuracy: 0.5829 - val_loss: 3.3704
# Epoch 286/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9809 - loss: 0.0380 - val_accuracy: 0.5677 - val_loss: 3.7103
# Epoch 287/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9811 - loss: 0.0375 - val_accuracy: 0.5615 - val_loss: 3.7956
# Epoch 288/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9806 - loss: 0.0391 - val_accuracy: 0.5664 - val_loss: 3.7332
# Epoch 289/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9816 - loss: 0.0375 - val_accuracy: 0.6074 - val_loss: 3.6390
# Epoch 290/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9795 - loss: 0.0403 - val_accuracy: 0.5686 - val_loss: 3.9933
# Epoch 291/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9814 - loss: 0.0391 - val_accuracy: 0.5664 - val_loss: 3.7539
# Epoch 292/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9809 - loss: 0.0390 - val_accuracy: 0.5655 - val_loss: 3.5256
# Epoch 293/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9803 - loss: 0.0389 - val_accuracy: 0.5646 - val_loss: 3.9317
# Epoch 294/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9821 - loss: 0.0374 - val_accuracy: 0.5865 - val_loss: 3.9905
# Epoch 295/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9782 - loss: 0.0405 - val_accuracy: 0.5490 - val_loss: 3.9909
# Epoch 296/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0400 - val_accuracy: 0.5682 - val_loss: 3.9919
# Epoch 297/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9797 - loss: 0.0394 - val_accuracy: 0.5673 - val_loss: 3.5440
# Epoch 298/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9806 - loss: 0.0387 - val_accuracy: 0.5789 - val_loss: 3.4029
# Epoch 299/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9788 - loss: 0.0423 - val_accuracy: 0.5686 - val_loss: 3.7683
# Epoch 300/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9818 - loss: 0.0366 - val_accuracy: 0.5597 - val_loss: 4.0243

# %% [markdown]
# #### 손실 그래프 시각화

# %%
# 손실 그래프 시각화
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 2-5. 모델 평가

# %%
y_pred = model.predict(X_test)
y_pred_class = (y_pred > 0.5).astype("int32")

print(classification_report(y_test, y_pred_class))
print(confusion_matrix(y_test, y_pred_class))
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred_class), display_labels=[0,1])
disp.plot()
plt.show()
# Out:
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.81      0.88      2822
#          1.0       0.93      0.99      0.96      6794
#
#     accuracy                           0.94      9616
#    macro avg       0.95      0.90      0.92      9616
# weighted avg       0.94      0.94      0.93      9616
#
# [[2290  532]
#  [  85 6709]]

# %%
# F1 Score 및 Accuracy 계산
accuracy = accuracy_score(y_test, y_pred_class)
f1 = f1_score(y_test, y_pred_class)

print(f'Accuracy: {accuracy:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.9358
# F1 Score: 0.9560

# %% [markdown]
# ### 2-6. 모델 개선(1) - 전처리 수정 및 모델 재훈련

# %% [markdown]
# #### 클래스 불균형 문제 해결(SMOTE)
# - SMOTE(Synthetic Minority Over-sampling Technique)는 불균형 데이터셋에서 소수 클래스의 데이터를 증가시켜 데이터 균형을 맞추는 오버샘플링 기법입니다.
#
#     |<b>SMOTE 작동방식</b> |
#     | :--: |
#     | ![](https://miro.medium.com/v2/resize:fit:720/format:webp/1*CeOd_Wbn7O6kpjSTKTIUog.png)|
#     | 출처:https://medium.com/@parthdholakiya180/smote-synthetic-minority-over-sampling-technique-4d5a5d69d720|

# %%
# !pip install imbalanced-learn==0.9.0
# Out:
# Requirement already satisfied: imbalanced-learn==0.9.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (0.9.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from imbalanced-learn==0.9.0) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from imbalanced-learn==0.9.0) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from imbalanced-learn==0.9.0) (1.5.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from imbalanced-learn==0.9.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\han\miniconda3\envs\hyundai_equip_6\lib\site-packages (from imbalanced-learn==0.9.0) (3.5.0)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train, y_train)

# %%
unique, counts = np.unique(y_train, return_counts=True)
print(np.asarray((unique, counts), dtype=int).T)
# Out:
# [[    0  6581]
#  [    1 15851]]

# %%
pd.Series(y_res).value_counts()
# Out:
# 1.0    15851
# 0.0    15851
# Name: count, dtype: int64

# %%
# AI 모델 디자인
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 모델 학습
history = model.fit(X_res, y_res, epochs=epochs, batch_size=batch_size, validation_split=0.1, shuffle=True)

# 손실 그래프 시각화
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# 모델 평가
y_pred = model.predict(X_test)
y_pred_class = (y_pred > 0.5).astype("int32")

print(classification_report(y_test, y_pred_class))
print(confusion_matrix(y_test, y_pred_class))
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred_class), display_labels=[0,1])
disp.plot()
plt.show()
# Out:
# Epoch 1/300
# C:\Users\Han\Miniconda3\envs\hyundai_equip_6\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6500 - loss: 0.6428 - val_accuracy: 0.5875 - val_loss: 0.6538
# Epoch 2/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7187 - loss: 0.5512 - val_accuracy: 0.7625 - val_loss: 0.5344
# Epoch 3/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7886 - loss: 0.4693 - val_accuracy: 0.8152 - val_loss: 0.4813
# Epoch 4/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8280 - loss: 0.4005 - val_accuracy: 0.8546 - val_loss: 0.3850
# Epoch 5/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8524 - loss: 0.3507 - val_accuracy: 0.8934 - val_loss: 0.3304
# Epoch 6/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8611 - loss: 0.3279 - val_accuracy: 0.9480 - val_loss: 0.2508
# Epoch 7/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8801 - loss: 0.2999 - val_accuracy: 0.8827 - val_loss: 0.3238
# Epoch 8/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8858 - loss: 0.2802 - val_accuracy: 0.9234 - val_loss: 0.2843
# Epoch 9/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9015 - loss: 0.2543 - val_accuracy: 0.9363 - val_loss: 0.2520
# Epoch 10/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9033 - loss: 0.2436 - val_accuracy: 0.9502 - val_loss: 0.2039
# Epoch 11/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9057 - loss: 0.2334 - val_accuracy: 0.9451 - val_loss: 0.2015
# Epoch 12/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9058 - loss: 0.2243 - val_accuracy: 0.9568 - val_loss: 0.1757
# Epoch 13/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9119 - loss: 0.2128 - val_accuracy: 0.9215 - val_loss: 0.2477
# Epoch 14/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9103 - loss: 0.2047 - val_accuracy: 0.9492 - val_loss: 0.1753
# Epoch 15/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9087 - loss: 0.2069 - val_accuracy: 0.9265 - val_loss: 0.2192
# Epoch 16/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.1957 - val_accuracy: 0.9417 - val_loss: 0.1913
# Epoch 17/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9176 - loss: 0.1910 - val_accuracy: 0.9495 - val_loss: 0.1732
# Epoch 18/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9212 - loss: 0.1838 - val_accuracy: 0.9205 - val_loss: 0.2371
# Epoch 19/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9197 - loss: 0.1806 - val_accuracy: 0.9499 - val_loss: 0.1749
# Epoch 20/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9220 - loss: 0.1786 - val_accuracy: 0.9407 - val_loss: 0.1855
# Epoch 21/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9247 - loss: 0.1701 - val_accuracy: 0.9502 - val_loss: 0.1635
# Epoch 22/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9270 - loss: 0.1664 - val_accuracy: 0.9458 - val_loss: 0.1753
# Epoch 23/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9298 - loss: 0.1613 - val_accuracy: 0.9518 - val_loss: 0.1557
# Epoch 24/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9330 - loss: 0.1557 - val_accuracy: 0.9152 - val_loss: 0.2164
# Epoch 25/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9292 - loss: 0.1600 - val_accuracy: 0.9659 - val_loss: 0.1344
# Epoch 26/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9340 - loss: 0.1532 - val_accuracy: 0.9650 - val_loss: 0.1305
# Epoch 27/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9339 - loss: 0.1531 - val_accuracy: 0.9581 - val_loss: 0.1446
# Epoch 28/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9345 - loss: 0.1508 - val_accuracy: 0.9470 - val_loss: 0.1600
# Epoch 29/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9371 - loss: 0.1473 - val_accuracy: 0.9354 - val_loss: 0.1777
# Epoch 30/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9390 - loss: 0.1441 - val_accuracy: 0.9678 - val_loss: 0.1197
# Epoch 31/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9392 - loss: 0.1420 - val_accuracy: 0.9558 - val_loss: 0.1343
# Epoch 32/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9440 - loss: 0.1359 - val_accuracy: 0.9584 - val_loss: 0.1284
# Epoch 33/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9409 - loss: 0.1396 - val_accuracy: 0.9615 - val_loss: 0.1217
# Epoch 34/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9418 - loss: 0.1353 - val_accuracy: 0.9707 - val_loss: 0.1111
# Epoch 35/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9424 - loss: 0.1339 - val_accuracy: 0.9603 - val_loss: 0.1240
# Epoch 36/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9413 - loss: 0.1362 - val_accuracy: 0.9480 - val_loss: 0.1545
# Epoch 37/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9397 - loss: 0.1377 - val_accuracy: 0.9637 - val_loss: 0.1284
# Epoch 38/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9407 - loss: 0.1350 - val_accuracy: 0.9722 - val_loss: 0.0926
# Epoch 39/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9443 - loss: 0.1309 - val_accuracy: 0.9540 - val_loss: 0.1367
# Epoch 40/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9433 - loss: 0.1294 - val_accuracy: 0.9558 - val_loss: 0.1352
# Epoch 41/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9440 - loss: 0.1290 - val_accuracy: 0.9470 - val_loss: 0.1469
# Epoch 42/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9457 - loss: 0.1271 - val_accuracy: 0.9436 - val_loss: 0.1512
# Epoch 43/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9420 - loss: 0.1269 - val_accuracy: 0.9650 - val_loss: 0.1006
# Epoch 44/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9449 - loss: 0.1253 - val_accuracy: 0.9707 - val_loss: 0.1100
# Epoch 45/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9433 - loss: 0.1255 - val_accuracy: 0.9596 - val_loss: 0.1153
# Epoch 46/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9443 - loss: 0.1213 - val_accuracy: 0.9603 - val_loss: 0.1207
# Epoch 47/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9453 - loss: 0.1235 - val_accuracy: 0.9704 - val_loss: 0.1085
# Epoch 48/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9468 - loss: 0.1183 - val_accuracy: 0.9568 - val_loss: 0.1157
# Epoch 49/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9462 - loss: 0.1184 - val_accuracy: 0.9612 - val_loss: 0.1158
# Epoch 50/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9455 - loss: 0.1193 - val_accuracy: 0.9738 - val_loss: 0.0924
# Epoch 51/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9461 - loss: 0.1188 - val_accuracy: 0.9804 - val_loss: 0.0783
# Epoch 52/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9466 - loss: 0.1188 - val_accuracy: 0.9527 - val_loss: 0.1223
# Epoch 53/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9462 - loss: 0.1150 - val_accuracy: 0.9634 - val_loss: 0.1057
# Epoch 54/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9492 - loss: 0.1127 - val_accuracy: 0.9675 - val_loss: 0.1003
# Epoch 55/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9477 - loss: 0.1157 - val_accuracy: 0.9782 - val_loss: 0.0834
# Epoch 56/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9494 - loss: 0.1151 - val_accuracy: 0.9524 - val_loss: 0.1220
# Epoch 57/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9480 - loss: 0.1134 - val_accuracy: 0.9609 - val_loss: 0.1045
# Epoch 58/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9488 - loss: 0.1138 - val_accuracy: 0.9587 - val_loss: 0.1161
# Epoch 59/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9500 - loss: 0.1113 - val_accuracy: 0.9868 - val_loss: 0.0711
# Epoch 60/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9469 - loss: 0.1137 - val_accuracy: 0.9675 - val_loss: 0.0943
# Epoch 61/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9503 - loss: 0.1090 - val_accuracy: 0.9574 - val_loss: 0.1129
# Epoch 62/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9525 - loss: 0.1082 - val_accuracy: 0.9590 - val_loss: 0.1065
# Epoch 63/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9505 - loss: 0.1071 - val_accuracy: 0.9729 - val_loss: 0.0876
# Epoch 64/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9526 - loss: 0.1052 - val_accuracy: 0.9880 - val_loss: 0.0663
# Epoch 65/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9533 - loss: 0.1064 - val_accuracy: 0.9877 - val_loss: 0.0679
# Epoch 66/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9536 - loss: 0.1049 - val_accuracy: 0.9842 - val_loss: 0.0758
# Epoch 67/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9525 - loss: 0.1076 - val_accuracy: 0.9467 - val_loss: 0.1384
# Epoch 68/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9528 - loss: 0.1040 - val_accuracy: 0.9713 - val_loss: 0.0952
# Epoch 69/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9518 - loss: 0.1038 - val_accuracy: 0.9656 - val_loss: 0.1014
# Epoch 70/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9551 - loss: 0.1009 - val_accuracy: 0.9656 - val_loss: 0.0973
# Epoch 71/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9543 - loss: 0.0984 - val_accuracy: 0.9603 - val_loss: 0.1037
# Epoch 72/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9552 - loss: 0.0987 - val_accuracy: 0.9521 - val_loss: 0.1147
# Epoch 73/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9554 - loss: 0.0982 - val_accuracy: 0.9599 - val_loss: 0.1035
# Epoch 74/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9545 - loss: 0.1012 - val_accuracy: 0.9659 - val_loss: 0.0983
# Epoch 75/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9541 - loss: 0.1005 - val_accuracy: 0.9786 - val_loss: 0.0788
# Epoch 76/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9569 - loss: 0.0946 - val_accuracy: 0.9842 - val_loss: 0.0741
# Epoch 77/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9565 - loss: 0.0953 - val_accuracy: 0.9924 - val_loss: 0.0539
# Epoch 78/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9548 - loss: 0.0984 - val_accuracy: 0.9934 - val_loss: 0.0556
# Epoch 79/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9561 - loss: 0.0966 - val_accuracy: 0.9741 - val_loss: 0.0849
# Epoch 80/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9589 - loss: 0.0909 - val_accuracy: 0.9697 - val_loss: 0.0951
# Epoch 81/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.0920 - val_accuracy: 0.9814 - val_loss: 0.0736
# Epoch 82/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9605 - loss: 0.0880 - val_accuracy: 0.9864 - val_loss: 0.0642
# Epoch 83/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9600 - loss: 0.0894 - val_accuracy: 0.9804 - val_loss: 0.0748
# Epoch 84/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9586 - loss: 0.0908 - val_accuracy: 0.9804 - val_loss: 0.0731
# Epoch 85/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9593 - loss: 0.0903 - val_accuracy: 0.9555 - val_loss: 0.1097
# Epoch 86/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9596 - loss: 0.0895 - val_accuracy: 0.9603 - val_loss: 0.0974
# Epoch 87/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9596 - loss: 0.0895 - val_accuracy: 0.9845 - val_loss: 0.0642
# Epoch 88/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9599 - loss: 0.0880 - val_accuracy: 0.9748 - val_loss: 0.0876
# Epoch 89/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9605 - loss: 0.0873 - val_accuracy: 0.9811 - val_loss: 0.0686
# Epoch 90/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9602 - loss: 0.0853 - val_accuracy: 0.9820 - val_loss: 0.0679
# Epoch 91/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9621 - loss: 0.0863 - val_accuracy: 0.9773 - val_loss: 0.0729
# Epoch 92/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9615 - loss: 0.0854 - val_accuracy: 0.9577 - val_loss: 0.0906
# Epoch 93/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9607 - loss: 0.0864 - val_accuracy: 0.9593 - val_loss: 0.0939
# Epoch 94/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9599 - loss: 0.0854 - val_accuracy: 0.9461 - val_loss: 0.1228
# Epoch 95/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.0891 - val_accuracy: 0.9726 - val_loss: 0.0841
# Epoch 96/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9617 - loss: 0.0843 - val_accuracy: 0.9804 - val_loss: 0.0683
# Epoch 97/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9624 - loss: 0.0821 - val_accuracy: 0.9814 - val_loss: 0.0657
# Epoch 98/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9640 - loss: 0.0792 - val_accuracy: 0.9729 - val_loss: 0.0764
# Epoch 99/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.0827 - val_accuracy: 0.9849 - val_loss: 0.0727
# Epoch 100/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.0834 - val_accuracy: 0.9855 - val_loss: 0.0547
# Epoch 101/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9617 - loss: 0.0847 - val_accuracy: 0.9795 - val_loss: 0.0673
# Epoch 102/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.0799 - val_accuracy: 0.9732 - val_loss: 0.0744
# Epoch 103/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9638 - loss: 0.0792 - val_accuracy: 0.9868 - val_loss: 0.0544
# Epoch 104/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9654 - loss: 0.0769 - val_accuracy: 0.9596 - val_loss: 0.1021
# Epoch 105/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9645 - loss: 0.0798 - val_accuracy: 0.9804 - val_loss: 0.0631
# Epoch 106/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.0773 - val_accuracy: 0.9612 - val_loss: 0.0978
# Epoch 107/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.0767 - val_accuracy: 0.9647 - val_loss: 0.0889
# Epoch 108/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.0788 - val_accuracy: 0.9741 - val_loss: 0.0815
# Epoch 109/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.0807 - val_accuracy: 0.9486 - val_loss: 0.1054
# Epoch 110/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.0801 - val_accuracy: 0.9855 - val_loss: 0.0555
# Epoch 111/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.0745 - val_accuracy: 0.9827 - val_loss: 0.0596
# Epoch 112/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.0754 - val_accuracy: 0.9637 - val_loss: 0.0839
# Epoch 113/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.0769 - val_accuracy: 0.9745 - val_loss: 0.0750
# Epoch 114/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.0743 - val_accuracy: 0.9820 - val_loss: 0.0571
# Epoch 115/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9653 - loss: 0.0744 - val_accuracy: 0.9603 - val_loss: 0.0834
# Epoch 116/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.0761 - val_accuracy: 0.9902 - val_loss: 0.0500
# Epoch 117/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9672 - loss: 0.0733 - val_accuracy: 0.9877 - val_loss: 0.0533
# Epoch 118/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.0729 - val_accuracy: 0.9726 - val_loss: 0.0759
# Epoch 119/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.0729 - val_accuracy: 0.9817 - val_loss: 0.0578
# Epoch 120/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.0729 - val_accuracy: 0.9704 - val_loss: 0.0729
# Epoch 121/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.0726 - val_accuracy: 0.9776 - val_loss: 0.0617
# Epoch 122/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9677 - loss: 0.0726 - val_accuracy: 0.9804 - val_loss: 0.0635
# Epoch 123/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9672 - loss: 0.0730 - val_accuracy: 0.9871 - val_loss: 0.0467
# Epoch 124/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9675 - loss: 0.0704 - val_accuracy: 0.9899 - val_loss: 0.0473
# Epoch 125/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.0720 - val_accuracy: 0.9748 - val_loss: 0.0684
# Epoch 126/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.0716 - val_accuracy: 0.9902 - val_loss: 0.0439
# Epoch 127/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.0719 - val_accuracy: 0.9795 - val_loss: 0.0667
# Epoch 128/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9667 - loss: 0.0715 - val_accuracy: 0.9628 - val_loss: 0.0836
# Epoch 129/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9675 - loss: 0.0711 - val_accuracy: 0.9669 - val_loss: 0.0791
# Epoch 130/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9677 - loss: 0.0699 - val_accuracy: 0.9776 - val_loss: 0.0621
# Epoch 131/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9687 - loss: 0.0702 - val_accuracy: 0.9893 - val_loss: 0.0430
# Epoch 132/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.0710 - val_accuracy: 0.9801 - val_loss: 0.0519
# Epoch 133/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9688 - loss: 0.0681 - val_accuracy: 0.9659 - val_loss: 0.0823
# Epoch 134/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9693 - loss: 0.0669 - val_accuracy: 0.9823 - val_loss: 0.0544
# Epoch 135/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9708 - loss: 0.0646 - val_accuracy: 0.9868 - val_loss: 0.0484
# Epoch 136/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9709 - loss: 0.0649 - val_accuracy: 0.9779 - val_loss: 0.0616
# Epoch 137/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.0656 - val_accuracy: 0.9868 - val_loss: 0.0439
# Epoch 138/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.0695 - val_accuracy: 0.9615 - val_loss: 0.0728
# Epoch 139/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9706 - loss: 0.0666 - val_accuracy: 0.9741 - val_loss: 0.0678
# Epoch 140/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9701 - loss: 0.0645 - val_accuracy: 0.9902 - val_loss: 0.0447
# Epoch 141/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9711 - loss: 0.0647 - val_accuracy: 0.9675 - val_loss: 0.0681
# Epoch 142/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.0680 - val_accuracy: 0.9625 - val_loss: 0.0799
# Epoch 143/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9686 - loss: 0.0672 - val_accuracy: 0.9726 - val_loss: 0.0625
# Epoch 144/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9687 - loss: 0.0667 - val_accuracy: 0.9656 - val_loss: 0.0822
# Epoch 145/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.0652 - val_accuracy: 0.9707 - val_loss: 0.0653
# Epoch 146/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.0638 - val_accuracy: 0.9681 - val_loss: 0.0703
# Epoch 147/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9711 - loss: 0.0647 - val_accuracy: 0.9767 - val_loss: 0.0613
# Epoch 148/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9717 - loss: 0.0627 - val_accuracy: 0.9827 - val_loss: 0.0550
# Epoch 149/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9713 - loss: 0.0622 - val_accuracy: 0.9877 - val_loss: 0.0462
# Epoch 150/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9726 - loss: 0.0610 - val_accuracy: 0.9880 - val_loss: 0.0426
# Epoch 151/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9698 - loss: 0.0644 - val_accuracy: 0.9773 - val_loss: 0.0568
# Epoch 152/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9702 - loss: 0.0640 - val_accuracy: 0.9883 - val_loss: 0.0426
# Epoch 153/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9730 - loss: 0.0600 - val_accuracy: 0.9745 - val_loss: 0.0605
# Epoch 154/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9715 - loss: 0.0660 - val_accuracy: 0.9833 - val_loss: 0.0518
# Epoch 155/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9738 - loss: 0.0599 - val_accuracy: 0.9905 - val_loss: 0.0430
# Epoch 156/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9715 - loss: 0.0657 - val_accuracy: 0.9845 - val_loss: 0.0487
# Epoch 157/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9720 - loss: 0.0616 - val_accuracy: 0.9669 - val_loss: 0.0747
# Epoch 158/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9727 - loss: 0.0613 - val_accuracy: 0.9817 - val_loss: 0.0491
# Epoch 159/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.0615 - val_accuracy: 0.9871 - val_loss: 0.0447
# Epoch 160/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9730 - loss: 0.0601 - val_accuracy: 0.9836 - val_loss: 0.0503
# Epoch 161/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9721 - loss: 0.0601 - val_accuracy: 0.9874 - val_loss: 0.0449
# Epoch 162/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9739 - loss: 0.0578 - val_accuracy: 0.9694 - val_loss: 0.0651
# Epoch 163/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9716 - loss: 0.0608 - val_accuracy: 0.9685 - val_loss: 0.0714
# Epoch 164/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9722 - loss: 0.0613 - val_accuracy: 0.9757 - val_loss: 0.0591
# Epoch 165/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9744 - loss: 0.0581 - val_accuracy: 0.9830 - val_loss: 0.0457
# Epoch 166/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9708 - loss: 0.0626 - val_accuracy: 0.9836 - val_loss: 0.0541
# Epoch 167/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9735 - loss: 0.0579 - val_accuracy: 0.9861 - val_loss: 0.0441
# Epoch 168/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.0596 - val_accuracy: 0.9931 - val_loss: 0.0342
# Epoch 169/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.0602 - val_accuracy: 0.9896 - val_loss: 0.0405
# Epoch 170/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9745 - loss: 0.0579 - val_accuracy: 0.9795 - val_loss: 0.0502
# Epoch 171/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9729 - loss: 0.0576 - val_accuracy: 0.9713 - val_loss: 0.0595
# Epoch 172/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.0615 - val_accuracy: 0.9883 - val_loss: 0.0422
# Epoch 173/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.0587 - val_accuracy: 0.9823 - val_loss: 0.0428
# Epoch 174/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9734 - loss: 0.0569 - val_accuracy: 0.9905 - val_loss: 0.0423
# Epoch 175/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9738 - loss: 0.0582 - val_accuracy: 0.9735 - val_loss: 0.0560
# Epoch 176/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9739 - loss: 0.0592 - val_accuracy: 0.9849 - val_loss: 0.0467
# Epoch 177/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.0595 - val_accuracy: 0.9868 - val_loss: 0.0410
# Epoch 178/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.0577 - val_accuracy: 0.9918 - val_loss: 0.0365
# Epoch 179/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9724 - loss: 0.0596 - val_accuracy: 0.9795 - val_loss: 0.0508
# Epoch 180/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9742 - loss: 0.0566 - val_accuracy: 0.9801 - val_loss: 0.0485
# Epoch 181/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9736 - loss: 0.0580 - val_accuracy: 0.9779 - val_loss: 0.0559
# Epoch 182/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9736 - loss: 0.0577 - val_accuracy: 0.9656 - val_loss: 0.0697
# Epoch 183/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.0602 - val_accuracy: 0.9864 - val_loss: 0.0416
# Epoch 184/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9741 - loss: 0.0559 - val_accuracy: 0.9713 - val_loss: 0.0563
# Epoch 185/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9722 - loss: 0.0576 - val_accuracy: 0.9798 - val_loss: 0.0486
# Epoch 186/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9752 - loss: 0.0548 - val_accuracy: 0.9634 - val_loss: 0.0645
# Epoch 187/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9730 - loss: 0.0565 - val_accuracy: 0.9893 - val_loss: 0.0400
# Epoch 188/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9759 - loss: 0.0534 - val_accuracy: 0.9893 - val_loss: 0.0381
# Epoch 189/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9752 - loss: 0.0546 - val_accuracy: 0.9909 - val_loss: 0.0338
# Epoch 190/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9724 - loss: 0.0593 - val_accuracy: 0.9886 - val_loss: 0.0410
# Epoch 191/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9748 - loss: 0.0553 - val_accuracy: 0.9776 - val_loss: 0.0501
# Epoch 192/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9745 - loss: 0.0564 - val_accuracy: 0.9555 - val_loss: 0.0794
# Epoch 193/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9720 - loss: 0.0581 - val_accuracy: 0.9817 - val_loss: 0.0439
# Epoch 194/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9763 - loss: 0.0518 - val_accuracy: 0.9858 - val_loss: 0.0461
# Epoch 195/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9737 - loss: 0.0565 - val_accuracy: 0.9700 - val_loss: 0.0588
# Epoch 196/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9762 - loss: 0.0525 - val_accuracy: 0.9823 - val_loss: 0.0428
# Epoch 197/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9749 - loss: 0.0549 - val_accuracy: 0.9666 - val_loss: 0.0664
# Epoch 198/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.0560 - val_accuracy: 0.9760 - val_loss: 0.0487
# Epoch 199/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9750 - loss: 0.0537 - val_accuracy: 0.9836 - val_loss: 0.0442
# Epoch 200/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.0528 - val_accuracy: 0.9628 - val_loss: 0.0673
# Epoch 201/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9746 - loss: 0.0539 - val_accuracy: 0.9836 - val_loss: 0.0452
# Epoch 202/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.0551 - val_accuracy: 0.9883 - val_loss: 0.0341
# Epoch 203/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0520 - val_accuracy: 0.9845 - val_loss: 0.0425
# Epoch 204/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0533 - val_accuracy: 0.9808 - val_loss: 0.0453
# Epoch 205/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9739 - loss: 0.0556 - val_accuracy: 0.9909 - val_loss: 0.0339
# Epoch 206/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0524 - val_accuracy: 0.9833 - val_loss: 0.0447
# Epoch 207/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.0510 - val_accuracy: 0.9795 - val_loss: 0.0483
# Epoch 208/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9757 - loss: 0.0526 - val_accuracy: 0.9918 - val_loss: 0.0314
# Epoch 209/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9746 - loss: 0.0545 - val_accuracy: 0.9707 - val_loss: 0.0616
# Epoch 210/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.0527 - val_accuracy: 0.9893 - val_loss: 0.0382
# Epoch 211/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9773 - loss: 0.0500 - val_accuracy: 0.9937 - val_loss: 0.0264
# Epoch 212/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.0553 - val_accuracy: 0.9827 - val_loss: 0.0412
# Epoch 213/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9771 - loss: 0.0498 - val_accuracy: 0.9808 - val_loss: 0.0488
# Epoch 214/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9752 - loss: 0.0524 - val_accuracy: 0.9830 - val_loss: 0.0427
# Epoch 215/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9770 - loss: 0.0488 - val_accuracy: 0.9716 - val_loss: 0.0525
# Epoch 216/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9763 - loss: 0.0526 - val_accuracy: 0.9760 - val_loss: 0.0496
# Epoch 217/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.0524 - val_accuracy: 0.9789 - val_loss: 0.0496
# Epoch 218/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9753 - loss: 0.0517 - val_accuracy: 0.9934 - val_loss: 0.0289
# Epoch 219/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9761 - loss: 0.0520 - val_accuracy: 0.9789 - val_loss: 0.0488
# Epoch 220/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0519 - val_accuracy: 0.9700 - val_loss: 0.0631
# Epoch 221/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9753 - loss: 0.0525 - val_accuracy: 0.9861 - val_loss: 0.0387
# Epoch 222/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9769 - loss: 0.0506 - val_accuracy: 0.9776 - val_loss: 0.0526
# Epoch 223/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9762 - loss: 0.0514 - val_accuracy: 0.9795 - val_loss: 0.0452
# Epoch 224/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9750 - loss: 0.0525 - val_accuracy: 0.9861 - val_loss: 0.0423
# Epoch 225/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9773 - loss: 0.0511 - val_accuracy: 0.9735 - val_loss: 0.0537
# Epoch 226/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9760 - loss: 0.0515 - val_accuracy: 0.9905 - val_loss: 0.0336
# Epoch 227/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9768 - loss: 0.0492 - val_accuracy: 0.9833 - val_loss: 0.0470
# Epoch 228/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9766 - loss: 0.0499 - val_accuracy: 0.9899 - val_loss: 0.0349
# Epoch 229/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9782 - loss: 0.0478 - val_accuracy: 0.9786 - val_loss: 0.0453
# Epoch 230/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0469 - val_accuracy: 0.9874 - val_loss: 0.0361
# Epoch 231/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9763 - loss: 0.0511 - val_accuracy: 0.9883 - val_loss: 0.0368
# Epoch 232/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9756 - loss: 0.0516 - val_accuracy: 0.9827 - val_loss: 0.0402
# Epoch 233/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9777 - loss: 0.0481 - val_accuracy: 0.9849 - val_loss: 0.0393
# Epoch 234/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9757 - loss: 0.0505 - val_accuracy: 0.9845 - val_loss: 0.0430
# Epoch 235/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9776 - loss: 0.0494 - val_accuracy: 0.9830 - val_loss: 0.0391
# Epoch 236/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9755 - loss: 0.0500 - val_accuracy: 0.9808 - val_loss: 0.0447
# Epoch 237/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.0482 - val_accuracy: 0.9858 - val_loss: 0.0426
# Epoch 238/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9774 - loss: 0.0479 - val_accuracy: 0.9760 - val_loss: 0.0479
# Epoch 239/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.0488 - val_accuracy: 0.9820 - val_loss: 0.0458
# Epoch 240/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9779 - loss: 0.0483 - val_accuracy: 0.9795 - val_loss: 0.0442
# Epoch 241/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.0481 - val_accuracy: 0.9845 - val_loss: 0.0386
# Epoch 242/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.0481 - val_accuracy: 0.9886 - val_loss: 0.0311
# Epoch 243/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9759 - loss: 0.0488 - val_accuracy: 0.9899 - val_loss: 0.0346
# Epoch 244/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.0491 - val_accuracy: 0.9798 - val_loss: 0.0466
# Epoch 245/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9760 - loss: 0.0502 - val_accuracy: 0.9823 - val_loss: 0.0431
# Epoch 246/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.0491 - val_accuracy: 0.9845 - val_loss: 0.0393
# Epoch 247/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.0477 - val_accuracy: 0.9786 - val_loss: 0.0488
# Epoch 248/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9765 - loss: 0.0475 - val_accuracy: 0.9776 - val_loss: 0.0487
# Epoch 249/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9776 - loss: 0.0481 - val_accuracy: 0.9877 - val_loss: 0.0385
# Epoch 250/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0497 - val_accuracy: 0.9902 - val_loss: 0.0333
# Epoch 251/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9753 - loss: 0.0506 - val_accuracy: 0.9659 - val_loss: 0.0573
# Epoch 252/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9761 - loss: 0.0489 - val_accuracy: 0.9924 - val_loss: 0.0310
# Epoch 253/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9778 - loss: 0.0481 - val_accuracy: 0.9905 - val_loss: 0.0324
# Epoch 254/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0455 - val_accuracy: 0.9833 - val_loss: 0.0377
# Epoch 255/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9785 - loss: 0.0471 - val_accuracy: 0.9767 - val_loss: 0.0497
# Epoch 256/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9775 - loss: 0.0473 - val_accuracy: 0.9776 - val_loss: 0.0418
# Epoch 257/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0470 - val_accuracy: 0.9798 - val_loss: 0.0436
# Epoch 258/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0500 - val_accuracy: 0.9953 - val_loss: 0.0242
# Epoch 259/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9764 - loss: 0.0484 - val_accuracy: 0.9827 - val_loss: 0.0429
# Epoch 260/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0498 - val_accuracy: 0.9713 - val_loss: 0.0575
# Epoch 261/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9756 - loss: 0.0508 - val_accuracy: 0.9927 - val_loss: 0.0281
# Epoch 262/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9759 - loss: 0.0503 - val_accuracy: 0.9798 - val_loss: 0.0477
# Epoch 263/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0463 - val_accuracy: 0.9912 - val_loss: 0.0290
# Epoch 264/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9790 - loss: 0.0481 - val_accuracy: 0.9722 - val_loss: 0.0511
# Epoch 265/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9777 - loss: 0.0469 - val_accuracy: 0.9845 - val_loss: 0.0364
# Epoch 266/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9765 - loss: 0.0464 - val_accuracy: 0.9858 - val_loss: 0.0359
# Epoch 267/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9794 - loss: 0.0449 - val_accuracy: 0.9874 - val_loss: 0.0309
# Epoch 268/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9765 - loss: 0.0474 - val_accuracy: 0.9798 - val_loss: 0.0453
# Epoch 269/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9784 - loss: 0.0466 - val_accuracy: 0.9817 - val_loss: 0.0489
# Epoch 270/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0462 - val_accuracy: 0.9905 - val_loss: 0.0320
# Epoch 271/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.0464 - val_accuracy: 0.9650 - val_loss: 0.0560
# Epoch 272/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9768 - loss: 0.0472 - val_accuracy: 0.9858 - val_loss: 0.0358
# Epoch 273/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9768 - loss: 0.0468 - val_accuracy: 0.9845 - val_loss: 0.0340
# Epoch 274/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9786 - loss: 0.0456 - val_accuracy: 0.9861 - val_loss: 0.0369
# Epoch 275/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0449 - val_accuracy: 0.9767 - val_loss: 0.0484
# Epoch 276/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0452 - val_accuracy: 0.9855 - val_loss: 0.0364
# Epoch 277/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0439 - val_accuracy: 0.9883 - val_loss: 0.0356
# Epoch 278/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9782 - loss: 0.0460 - val_accuracy: 0.9953 - val_loss: 0.0261
# Epoch 279/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9772 - loss: 0.0474 - val_accuracy: 0.9804 - val_loss: 0.0427
# Epoch 280/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0459 - val_accuracy: 0.9808 - val_loss: 0.0399
# Epoch 281/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.0470 - val_accuracy: 0.9562 - val_loss: 0.0708
# Epoch 282/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9781 - loss: 0.0457 - val_accuracy: 0.9795 - val_loss: 0.0428
# Epoch 283/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.0453 - val_accuracy: 0.9905 - val_loss: 0.0285
# Epoch 284/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.0459 - val_accuracy: 0.9817 - val_loss: 0.0441
# Epoch 285/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9795 - loss: 0.0450 - val_accuracy: 0.9855 - val_loss: 0.0383
# Epoch 286/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9784 - loss: 0.0455 - val_accuracy: 0.9940 - val_loss: 0.0315
# Epoch 287/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9759 - loss: 0.0501 - val_accuracy: 0.9798 - val_loss: 0.0489
# Epoch 288/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.0443 - val_accuracy: 0.9883 - val_loss: 0.0323
# Epoch 289/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9788 - loss: 0.0454 - val_accuracy: 0.9704 - val_loss: 0.0560
# Epoch 290/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0445 - val_accuracy: 0.9811 - val_loss: 0.0456
# Epoch 291/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0439 - val_accuracy: 0.9710 - val_loss: 0.0456
# Epoch 292/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9794 - loss: 0.0435 - val_accuracy: 0.9830 - val_loss: 0.0397
# Epoch 293/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0428 - val_accuracy: 0.9902 - val_loss: 0.0307
# Epoch 294/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9799 - loss: 0.0437 - val_accuracy: 0.9880 - val_loss: 0.0316
# Epoch 295/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9778 - loss: 0.0456 - val_accuracy: 0.9760 - val_loss: 0.0453
# Epoch 296/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0452 - val_accuracy: 0.9836 - val_loss: 0.0394
# Epoch 297/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0445 - val_accuracy: 0.9710 - val_loss: 0.0574
# Epoch 298/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.0456 - val_accuracy: 0.9855 - val_loss: 0.0359
# Epoch 299/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9790 - loss: 0.0445 - val_accuracy: 0.9672 - val_loss: 0.0527
# Epoch 300/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0426 - val_accuracy: 0.9839 - val_loss: 0.0368
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95      2822
#          1.0       0.99      0.97      0.98      6794
#
#     accuracy                           0.97      9616
#    macro avg       0.96      0.97      0.96      9616
# weighted avg       0.97      0.97      0.97      9616
#
# [[2739   83]
#  [ 216 6578]]

# %%
# F1 Score 및 Accuracy 계산
accuracy = accuracy_score(y_test, y_pred_class)
f1 = f1_score(y_test, y_pred_class)

print(f'Accuracy: {accuracy:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.9703
# F1 Score: 0.9789

# %% [markdown]
# ### 2-7. 모델 개선(2) - 하이퍼파라미터 튜닝

# %%
# 모델 재정의 및 학습
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_res, y_res, epochs=300, batch_size=1024, validation_split=0.1)

# 손실 그래프 시각화
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# 모델 평가
y_pred = model.predict(X_test)
y_pred_class = (y_pred > 0.5).astype("int32")

print(classification_report(y_test, y_pred_class))
print(confusion_matrix(y_test, y_pred_class))
# Out:
# Epoch 1/300
# C:\Users\Han\Miniconda3\envs\hyundai_equip_6\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6037 - loss: 0.6616 - val_accuracy: 0.6004 - val_loss: 0.6976
# Epoch 2/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7254 - loss: 0.5582 - val_accuracy: 0.7679 - val_loss: 0.5445
# Epoch 3/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7819 - loss: 0.4809 - val_accuracy: 0.8698 - val_loss: 0.4000
# Epoch 4/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8190 - loss: 0.4182 - val_accuracy: 0.9205 - val_loss: 0.3226
# Epoch 5/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8468 - loss: 0.3693 - val_accuracy: 0.9363 - val_loss: 0.3037
# Epoch 6/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8649 - loss: 0.3312 - val_accuracy: 0.9663 - val_loss: 0.2483
# Epoch 7/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8757 - loss: 0.3048 - val_accuracy: 0.9609 - val_loss: 0.2406
# Epoch 8/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8869 - loss: 0.2803 - val_accuracy: 0.9628 - val_loss: 0.2251
# Epoch 9/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8928 - loss: 0.2656 - val_accuracy: 0.9691 - val_loss: 0.2075
# Epoch 10/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8979 - loss: 0.2485 - val_accuracy: 0.9735 - val_loss: 0.1816
# Epoch 11/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9084 - loss: 0.2296 - val_accuracy: 0.9700 - val_loss: 0.1960
# Epoch 12/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9069 - loss: 0.2237 - val_accuracy: 0.9729 - val_loss: 0.1702
# Epoch 13/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9107 - loss: 0.2153 - val_accuracy: 0.9754 - val_loss: 0.1621
# Epoch 14/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9171 - loss: 0.2018 - val_accuracy: 0.9735 - val_loss: 0.1560
# Epoch 15/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9164 - loss: 0.1986 - val_accuracy: 0.9716 - val_loss: 0.1686
# Epoch 16/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9173 - loss: 0.1959 - val_accuracy: 0.9738 - val_loss: 0.1412
# Epoch 17/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9199 - loss: 0.1866 - val_accuracy: 0.9792 - val_loss: 0.1284
# Epoch 18/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9216 - loss: 0.1821 - val_accuracy: 0.9770 - val_loss: 0.1506
# Epoch 19/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9224 - loss: 0.1830 - val_accuracy: 0.9710 - val_loss: 0.1557
# Epoch 20/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9216 - loss: 0.1815 - val_accuracy: 0.9735 - val_loss: 0.1315
# Epoch 21/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9272 - loss: 0.1706 - val_accuracy: 0.9820 - val_loss: 0.1143
# Epoch 22/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9293 - loss: 0.1687 - val_accuracy: 0.9776 - val_loss: 0.1224
# Epoch 23/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9311 - loss: 0.1605 - val_accuracy: 0.9741 - val_loss: 0.1168
# Epoch 24/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9301 - loss: 0.1612 - val_accuracy: 0.9719 - val_loss: 0.1279
# Epoch 25/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9320 - loss: 0.1566 - val_accuracy: 0.9732 - val_loss: 0.1202
# Epoch 26/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9322 - loss: 0.1534 - val_accuracy: 0.9741 - val_loss: 0.1124
# Epoch 27/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9324 - loss: 0.1547 - val_accuracy: 0.9700 - val_loss: 0.1197
# Epoch 28/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9349 - loss: 0.1502 - val_accuracy: 0.9704 - val_loss: 0.1166
# Epoch 29/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9357 - loss: 0.1445 - val_accuracy: 0.9779 - val_loss: 0.1059
# Epoch 30/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9369 - loss: 0.1457 - val_accuracy: 0.9748 - val_loss: 0.1105
# Epoch 31/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9362 - loss: 0.1448 - val_accuracy: 0.9861 - val_loss: 0.0994
# Epoch 32/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.1475 - val_accuracy: 0.9726 - val_loss: 0.1059
# Epoch 33/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9372 - loss: 0.1396 - val_accuracy: 0.9795 - val_loss: 0.0903
# Epoch 34/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9384 - loss: 0.1372 - val_accuracy: 0.9839 - val_loss: 0.0900
# Epoch 35/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9403 - loss: 0.1338 - val_accuracy: 0.9732 - val_loss: 0.1020
# Epoch 36/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9411 - loss: 0.1329 - val_accuracy: 0.9804 - val_loss: 0.0919
# Epoch 37/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9391 - loss: 0.1344 - val_accuracy: 0.9811 - val_loss: 0.0876
# Epoch 38/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9399 - loss: 0.1312 - val_accuracy: 0.9836 - val_loss: 0.0901
# Epoch 39/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9426 - loss: 0.1291 - val_accuracy: 0.9801 - val_loss: 0.0949
# Epoch 40/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9421 - loss: 0.1295 - val_accuracy: 0.9741 - val_loss: 0.1013
# Epoch 41/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9399 - loss: 0.1313 - val_accuracy: 0.9842 - val_loss: 0.0862
# Epoch 42/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9425 - loss: 0.1295 - val_accuracy: 0.9795 - val_loss: 0.0958
# Epoch 43/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9415 - loss: 0.1245 - val_accuracy: 0.9637 - val_loss: 0.1143
# Epoch 44/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9457 - loss: 0.1210 - val_accuracy: 0.9861 - val_loss: 0.0845
# Epoch 45/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9442 - loss: 0.1208 - val_accuracy: 0.9811 - val_loss: 0.0924
# Epoch 46/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9464 - loss: 0.1212 - val_accuracy: 0.9918 - val_loss: 0.0746
# Epoch 47/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9460 - loss: 0.1209 - val_accuracy: 0.9893 - val_loss: 0.0773
# Epoch 48/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9464 - loss: 0.1187 - val_accuracy: 0.9858 - val_loss: 0.0821
# Epoch 49/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9446 - loss: 0.1205 - val_accuracy: 0.9849 - val_loss: 0.0789
# Epoch 50/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9469 - loss: 0.1184 - val_accuracy: 0.9845 - val_loss: 0.0794
# Epoch 51/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9471 - loss: 0.1175 - val_accuracy: 0.9798 - val_loss: 0.0853
# Epoch 52/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9491 - loss: 0.1122 - val_accuracy: 0.9801 - val_loss: 0.0882
# Epoch 53/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9475 - loss: 0.1145 - val_accuracy: 0.9902 - val_loss: 0.0723
# Epoch 54/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9473 - loss: 0.1128 - val_accuracy: 0.9905 - val_loss: 0.0703
# Epoch 55/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1102 - val_accuracy: 0.9820 - val_loss: 0.0802
# Epoch 56/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9493 - loss: 0.1113 - val_accuracy: 0.9877 - val_loss: 0.0763
# Epoch 57/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9490 - loss: 0.1097 - val_accuracy: 0.9798 - val_loss: 0.0887
# Epoch 58/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9484 - loss: 0.1128 - val_accuracy: 0.9836 - val_loss: 0.0764
# Epoch 59/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9465 - loss: 0.1133 - val_accuracy: 0.9868 - val_loss: 0.0719
# Epoch 60/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9499 - loss: 0.1086 - val_accuracy: 0.9852 - val_loss: 0.0777
# Epoch 61/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9496 - loss: 0.1095 - val_accuracy: 0.9782 - val_loss: 0.0807
# Epoch 62/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9464 - loss: 0.1114 - val_accuracy: 0.9855 - val_loss: 0.0781
# Epoch 63/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9504 - loss: 0.1109 - val_accuracy: 0.9883 - val_loss: 0.0736
# Epoch 64/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9500 - loss: 0.1058 - val_accuracy: 0.9886 - val_loss: 0.0770
# Epoch 65/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9511 - loss: 0.1076 - val_accuracy: 0.9833 - val_loss: 0.0796
# Epoch 66/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9494 - loss: 0.1075 - val_accuracy: 0.9918 - val_loss: 0.0633
# Epoch 67/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9500 - loss: 0.1061 - val_accuracy: 0.9849 - val_loss: 0.0688
# Epoch 68/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9499 - loss: 0.1072 - val_accuracy: 0.9817 - val_loss: 0.0797
# Epoch 69/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9513 - loss: 0.1043 - val_accuracy: 0.9861 - val_loss: 0.0689
# Epoch 70/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9518 - loss: 0.1049 - val_accuracy: 0.9896 - val_loss: 0.0667
# Epoch 71/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9514 - loss: 0.1065 - val_accuracy: 0.9880 - val_loss: 0.0686
# Epoch 72/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9540 - loss: 0.1011 - val_accuracy: 0.9921 - val_loss: 0.0654
# Epoch 73/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9510 - loss: 0.1016 - val_accuracy: 0.9868 - val_loss: 0.0631
# Epoch 74/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9502 - loss: 0.1027 - val_accuracy: 0.9836 - val_loss: 0.0764
# Epoch 75/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9501 - loss: 0.1042 - val_accuracy: 0.9871 - val_loss: 0.0655
# Epoch 76/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9532 - loss: 0.1031 - val_accuracy: 0.9817 - val_loss: 0.0692
# Epoch 77/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9507 - loss: 0.1027 - val_accuracy: 0.9858 - val_loss: 0.0689
# Epoch 78/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9532 - loss: 0.0995 - val_accuracy: 0.9760 - val_loss: 0.0738
# Epoch 79/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9541 - loss: 0.0993 - val_accuracy: 0.9767 - val_loss: 0.0675
# Epoch 80/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9527 - loss: 0.0986 - val_accuracy: 0.9943 - val_loss: 0.0628
# Epoch 81/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9538 - loss: 0.1012 - val_accuracy: 0.9792 - val_loss: 0.0652
# Epoch 82/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9546 - loss: 0.1001 - val_accuracy: 0.9842 - val_loss: 0.0631
# Epoch 83/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9538 - loss: 0.0994 - val_accuracy: 0.9896 - val_loss: 0.0637
# Epoch 84/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9537 - loss: 0.0979 - val_accuracy: 0.9836 - val_loss: 0.0661
# Epoch 85/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9546 - loss: 0.0961 - val_accuracy: 0.9893 - val_loss: 0.0593
# Epoch 86/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9539 - loss: 0.1005 - val_accuracy: 0.9918 - val_loss: 0.0573
# Epoch 87/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9547 - loss: 0.0960 - val_accuracy: 0.9748 - val_loss: 0.0636
# Epoch 88/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9546 - loss: 0.0981 - val_accuracy: 0.9896 - val_loss: 0.0575
# Epoch 89/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9541 - loss: 0.0986 - val_accuracy: 0.9849 - val_loss: 0.0674
# Epoch 90/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9534 - loss: 0.0997 - val_accuracy: 0.9789 - val_loss: 0.0598
# Epoch 91/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9548 - loss: 0.0939 - val_accuracy: 0.9864 - val_loss: 0.0648
# Epoch 92/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9522 - loss: 0.0991 - val_accuracy: 0.9927 - val_loss: 0.0599
# Epoch 93/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9523 - loss: 0.0986 - val_accuracy: 0.9915 - val_loss: 0.0582
# Epoch 94/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.0919 - val_accuracy: 0.9921 - val_loss: 0.0527
# Epoch 95/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9550 - loss: 0.0954 - val_accuracy: 0.9946 - val_loss: 0.0512
# Epoch 96/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9555 - loss: 0.0947 - val_accuracy: 0.9722 - val_loss: 0.0652
# Epoch 97/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9554 - loss: 0.0971 - val_accuracy: 0.9931 - val_loss: 0.0584
# Epoch 98/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9555 - loss: 0.0957 - val_accuracy: 0.9741 - val_loss: 0.0610
# Epoch 99/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9551 - loss: 0.0932 - val_accuracy: 0.9934 - val_loss: 0.0513
# Epoch 100/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9545 - loss: 0.0933 - val_accuracy: 0.9902 - val_loss: 0.0602
# Epoch 101/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9565 - loss: 0.0933 - val_accuracy: 0.9902 - val_loss: 0.0598
# Epoch 102/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.0915 - val_accuracy: 0.9918 - val_loss: 0.0576
# Epoch 103/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9578 - loss: 0.0886 - val_accuracy: 0.9814 - val_loss: 0.0677
# Epoch 104/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9561 - loss: 0.0933 - val_accuracy: 0.9861 - val_loss: 0.0590
# Epoch 105/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9596 - loss: 0.0897 - val_accuracy: 0.9871 - val_loss: 0.0604
# Epoch 106/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.0908 - val_accuracy: 0.9918 - val_loss: 0.0525
# Epoch 107/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9565 - loss: 0.0925 - val_accuracy: 0.9912 - val_loss: 0.0545
# Epoch 108/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9553 - loss: 0.0940 - val_accuracy: 0.9890 - val_loss: 0.0541
# Epoch 109/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9571 - loss: 0.0884 - val_accuracy: 0.9915 - val_loss: 0.0572
# Epoch 110/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9588 - loss: 0.0882 - val_accuracy: 0.9886 - val_loss: 0.0525
# Epoch 111/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9572 - loss: 0.0889 - val_accuracy: 0.9883 - val_loss: 0.0542
# Epoch 112/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9567 - loss: 0.0883 - val_accuracy: 0.9845 - val_loss: 0.0531
# Epoch 113/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9580 - loss: 0.0899 - val_accuracy: 0.9940 - val_loss: 0.0529
# Epoch 114/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9553 - loss: 0.0905 - val_accuracy: 0.9839 - val_loss: 0.0532
# Epoch 115/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9552 - loss: 0.0950 - val_accuracy: 0.9896 - val_loss: 0.0556
# Epoch 116/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9571 - loss: 0.0893 - val_accuracy: 0.9830 - val_loss: 0.0628
# Epoch 117/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9574 - loss: 0.0916 - val_accuracy: 0.9950 - val_loss: 0.0499
# Epoch 118/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9562 - loss: 0.0904 - val_accuracy: 0.9931 - val_loss: 0.0535
# Epoch 119/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.0849 - val_accuracy: 0.9849 - val_loss: 0.0572
# Epoch 120/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9576 - loss: 0.0873 - val_accuracy: 0.9827 - val_loss: 0.0572
# Epoch 121/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.0898 - val_accuracy: 0.9842 - val_loss: 0.0600
# Epoch 122/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9574 - loss: 0.0897 - val_accuracy: 0.9748 - val_loss: 0.0592
# Epoch 123/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9583 - loss: 0.0883 - val_accuracy: 0.9773 - val_loss: 0.0599
# Epoch 124/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9554 - loss: 0.0900 - val_accuracy: 0.9855 - val_loss: 0.0517
# Epoch 125/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9589 - loss: 0.0848 - val_accuracy: 0.9921 - val_loss: 0.0521
# Epoch 126/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9588 - loss: 0.0867 - val_accuracy: 0.9804 - val_loss: 0.0557
# Epoch 127/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9568 - loss: 0.0852 - val_accuracy: 0.9886 - val_loss: 0.0592
# Epoch 128/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9576 - loss: 0.0913 - val_accuracy: 0.9842 - val_loss: 0.0515
# Epoch 129/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9597 - loss: 0.0886 - val_accuracy: 0.9763 - val_loss: 0.0600
# Epoch 130/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9597 - loss: 0.0822 - val_accuracy: 0.9937 - val_loss: 0.0515
# Epoch 131/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.0870 - val_accuracy: 0.9902 - val_loss: 0.0525
# Epoch 132/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9581 - loss: 0.0875 - val_accuracy: 0.9782 - val_loss: 0.0479
# Epoch 133/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.0882 - val_accuracy: 0.9858 - val_loss: 0.0585
# Epoch 134/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9593 - loss: 0.0870 - val_accuracy: 0.9748 - val_loss: 0.0568
# Epoch 135/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.0867 - val_accuracy: 0.9890 - val_loss: 0.0506
# Epoch 136/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.0896 - val_accuracy: 0.9842 - val_loss: 0.0581
# Epoch 137/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.0891 - val_accuracy: 0.9823 - val_loss: 0.0529
# Epoch 138/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9574 - loss: 0.0874 - val_accuracy: 0.9946 - val_loss: 0.0470
# Epoch 139/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9590 - loss: 0.0860 - val_accuracy: 0.9855 - val_loss: 0.0534
# Epoch 140/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9563 - loss: 0.0882 - val_accuracy: 0.9868 - val_loss: 0.0479
# Epoch 141/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.0829 - val_accuracy: 0.9833 - val_loss: 0.0486
# Epoch 142/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9586 - loss: 0.0851 - val_accuracy: 0.9868 - val_loss: 0.0517
# Epoch 143/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9549 - loss: 0.0885 - val_accuracy: 0.9820 - val_loss: 0.0569
# Epoch 144/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9578 - loss: 0.0879 - val_accuracy: 0.9915 - val_loss: 0.0481
# Epoch 145/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9570 - loss: 0.0898 - val_accuracy: 0.9909 - val_loss: 0.0464
# Epoch 146/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9592 - loss: 0.0857 - val_accuracy: 0.9874 - val_loss: 0.0483
# Epoch 147/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9611 - loss: 0.0848 - val_accuracy: 0.9830 - val_loss: 0.0564
# Epoch 148/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.0844 - val_accuracy: 0.9858 - val_loss: 0.0519
# Epoch 149/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9572 - loss: 0.0872 - val_accuracy: 0.9833 - val_loss: 0.0526
# Epoch 150/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9573 - loss: 0.0858 - val_accuracy: 0.9789 - val_loss: 0.0535
# Epoch 151/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.0836 - val_accuracy: 0.9827 - val_loss: 0.0483
# Epoch 152/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9589 - loss: 0.0831 - val_accuracy: 0.9710 - val_loss: 0.0583
# Epoch 153/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.0832 - val_accuracy: 0.9830 - val_loss: 0.0547
# Epoch 154/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9596 - loss: 0.0837 - val_accuracy: 0.9915 - val_loss: 0.0469
# Epoch 155/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.0852 - val_accuracy: 0.9931 - val_loss: 0.0436
# Epoch 156/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9597 - loss: 0.0859 - val_accuracy: 0.9845 - val_loss: 0.0559
# Epoch 157/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.0864 - val_accuracy: 0.9874 - val_loss: 0.0442
# Epoch 158/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9606 - loss: 0.0815 - val_accuracy: 0.9899 - val_loss: 0.0464
# Epoch 159/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9589 - loss: 0.0830 - val_accuracy: 0.9842 - val_loss: 0.0471
# Epoch 160/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9608 - loss: 0.0822 - val_accuracy: 0.9905 - val_loss: 0.0434
# Epoch 161/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9608 - loss: 0.0827 - val_accuracy: 0.9868 - val_loss: 0.0498
# Epoch 162/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9604 - loss: 0.0785 - val_accuracy: 0.9855 - val_loss: 0.0455
# Epoch 163/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9608 - loss: 0.0811 - val_accuracy: 0.9902 - val_loss: 0.0497
# Epoch 164/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.0834 - val_accuracy: 0.9738 - val_loss: 0.0484
# Epoch 165/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.0798 - val_accuracy: 0.9836 - val_loss: 0.0489
# Epoch 166/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.0854 - val_accuracy: 0.9767 - val_loss: 0.0529
# Epoch 167/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9608 - loss: 0.0787 - val_accuracy: 0.9773 - val_loss: 0.0520
# Epoch 168/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9599 - loss: 0.0811 - val_accuracy: 0.9792 - val_loss: 0.0553
# Epoch 169/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.0844 - val_accuracy: 0.9839 - val_loss: 0.0508
# Epoch 170/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.0834 - val_accuracy: 0.9789 - val_loss: 0.0494
# Epoch 171/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9608 - loss: 0.0799 - val_accuracy: 0.9880 - val_loss: 0.0496
# Epoch 172/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9603 - loss: 0.0826 - val_accuracy: 0.9760 - val_loss: 0.0514
# Epoch 173/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.0869 - val_accuracy: 0.9858 - val_loss: 0.0482
# Epoch 174/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.0843 - val_accuracy: 0.9814 - val_loss: 0.0492
# Epoch 175/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9594 - loss: 0.0875 - val_accuracy: 0.9798 - val_loss: 0.0497
# Epoch 176/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9609 - loss: 0.0795 - val_accuracy: 0.9726 - val_loss: 0.0592
# Epoch 177/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9629 - loss: 0.0783 - val_accuracy: 0.9751 - val_loss: 0.0502
# Epoch 178/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9614 - loss: 0.0798 - val_accuracy: 0.9877 - val_loss: 0.0478
# Epoch 179/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9616 - loss: 0.0779 - val_accuracy: 0.9779 - val_loss: 0.0470
# Epoch 180/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9605 - loss: 0.0788 - val_accuracy: 0.9871 - val_loss: 0.0493
# Epoch 181/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9591 - loss: 0.0831 - val_accuracy: 0.9811 - val_loss: 0.0493
# Epoch 182/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9629 - loss: 0.0784 - val_accuracy: 0.9763 - val_loss: 0.0569
# Epoch 183/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9623 - loss: 0.0819 - val_accuracy: 0.9741 - val_loss: 0.0568
# Epoch 184/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9633 - loss: 0.0784 - val_accuracy: 0.9849 - val_loss: 0.0465
# Epoch 185/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9620 - loss: 0.0791 - val_accuracy: 0.9839 - val_loss: 0.0439
# Epoch 186/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9607 - loss: 0.0776 - val_accuracy: 0.9795 - val_loss: 0.0435
# Epoch 187/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.0785 - val_accuracy: 0.9905 - val_loss: 0.0441
# Epoch 188/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9611 - loss: 0.0794 - val_accuracy: 0.9760 - val_loss: 0.0517
# Epoch 189/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9620 - loss: 0.0817 - val_accuracy: 0.9763 - val_loss: 0.0484
# Epoch 190/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9635 - loss: 0.0774 - val_accuracy: 0.9849 - val_loss: 0.0450
# Epoch 191/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.0773 - val_accuracy: 0.9801 - val_loss: 0.0434
# Epoch 192/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9606 - loss: 0.0795 - val_accuracy: 0.9877 - val_loss: 0.0451
# Epoch 193/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9631 - loss: 0.0762 - val_accuracy: 0.9811 - val_loss: 0.0477
# Epoch 194/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9629 - loss: 0.0791 - val_accuracy: 0.9855 - val_loss: 0.0466
# Epoch 195/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9622 - loss: 0.0812 - val_accuracy: 0.9741 - val_loss: 0.0477
# Epoch 196/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.0790 - val_accuracy: 0.9798 - val_loss: 0.0447
# Epoch 197/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9639 - loss: 0.0756 - val_accuracy: 0.9836 - val_loss: 0.0460
# Epoch 198/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9640 - loss: 0.0747 - val_accuracy: 0.9776 - val_loss: 0.0469
# Epoch 199/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9629 - loss: 0.0756 - val_accuracy: 0.9798 - val_loss: 0.0460
# Epoch 200/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9605 - loss: 0.0834 - val_accuracy: 0.9732 - val_loss: 0.0503
# Epoch 201/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9617 - loss: 0.0782 - val_accuracy: 0.9855 - val_loss: 0.0503
# Epoch 202/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.0783 - val_accuracy: 0.9858 - val_loss: 0.0445
# Epoch 203/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9634 - loss: 0.0762 - val_accuracy: 0.9801 - val_loss: 0.0499
# Epoch 204/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9589 - loss: 0.0803 - val_accuracy: 0.9798 - val_loss: 0.0495
# Epoch 205/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9601 - loss: 0.0803 - val_accuracy: 0.9757 - val_loss: 0.0528
# Epoch 206/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.0812 - val_accuracy: 0.9915 - val_loss: 0.0376
# Epoch 207/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9591 - loss: 0.0826 - val_accuracy: 0.9820 - val_loss: 0.0485
# Epoch 208/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.0775 - val_accuracy: 0.9700 - val_loss: 0.0538
# Epoch 209/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9613 - loss: 0.0800 - val_accuracy: 0.9741 - val_loss: 0.0508
# Epoch 210/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9617 - loss: 0.0772 - val_accuracy: 0.9773 - val_loss: 0.0528
# Epoch 211/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.0798 - val_accuracy: 0.9757 - val_loss: 0.0495
# Epoch 212/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9630 - loss: 0.0775 - val_accuracy: 0.9767 - val_loss: 0.0445
# Epoch 213/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.0793 - val_accuracy: 0.9741 - val_loss: 0.0481
# Epoch 214/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9637 - loss: 0.0759 - val_accuracy: 0.9751 - val_loss: 0.0551
# Epoch 215/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.0789 - val_accuracy: 0.9798 - val_loss: 0.0408
# Epoch 216/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9624 - loss: 0.0771 - val_accuracy: 0.9748 - val_loss: 0.0500
# Epoch 217/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.0795 - val_accuracy: 0.9786 - val_loss: 0.0477
# Epoch 218/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9614 - loss: 0.0773 - val_accuracy: 0.9773 - val_loss: 0.0435
# Epoch 219/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9632 - loss: 0.0758 - val_accuracy: 0.9804 - val_loss: 0.0445
# Epoch 220/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9644 - loss: 0.0729 - val_accuracy: 0.9722 - val_loss: 0.0471
# Epoch 221/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9610 - loss: 0.0784 - val_accuracy: 0.9776 - val_loss: 0.0493
# Epoch 222/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9624 - loss: 0.0763 - val_accuracy: 0.9871 - val_loss: 0.0438
# Epoch 223/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9592 - loss: 0.0785 - val_accuracy: 0.9754 - val_loss: 0.0501
# Epoch 224/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9617 - loss: 0.0792 - val_accuracy: 0.9754 - val_loss: 0.0472
# Epoch 225/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9614 - loss: 0.0778 - val_accuracy: 0.9773 - val_loss: 0.0536
# Epoch 226/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9594 - loss: 0.0808 - val_accuracy: 0.9763 - val_loss: 0.0486
# Epoch 227/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9593 - loss: 0.0793 - val_accuracy: 0.9732 - val_loss: 0.0502
# Epoch 228/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9617 - loss: 0.0782 - val_accuracy: 0.9713 - val_loss: 0.0546
# Epoch 229/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.0790 - val_accuracy: 0.9763 - val_loss: 0.0446
# Epoch 230/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.0740 - val_accuracy: 0.9760 - val_loss: 0.0442
# Epoch 231/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9624 - loss: 0.0749 - val_accuracy: 0.9776 - val_loss: 0.0490
# Epoch 232/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9613 - loss: 0.0769 - val_accuracy: 0.9827 - val_loss: 0.0386
# Epoch 233/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.0766 - val_accuracy: 0.9757 - val_loss: 0.0454
# Epoch 234/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9649 - loss: 0.0762 - val_accuracy: 0.9738 - val_loss: 0.0469
# Epoch 235/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9630 - loss: 0.0760 - val_accuracy: 0.9732 - val_loss: 0.0461
# Epoch 236/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9632 - loss: 0.0767 - val_accuracy: 0.9773 - val_loss: 0.0482
# Epoch 237/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.0769 - val_accuracy: 0.9814 - val_loss: 0.0501
# Epoch 238/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9642 - loss: 0.0756 - val_accuracy: 0.9782 - val_loss: 0.0481
# Epoch 239/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9627 - loss: 0.0768 - val_accuracy: 0.9751 - val_loss: 0.0532
# Epoch 240/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.0807 - val_accuracy: 0.9745 - val_loss: 0.0507
# Epoch 241/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.0768 - val_accuracy: 0.9776 - val_loss: 0.0445
# Epoch 242/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9617 - loss: 0.0760 - val_accuracy: 0.9779 - val_loss: 0.0442
# Epoch 243/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9622 - loss: 0.0775 - val_accuracy: 0.9814 - val_loss: 0.0406
# Epoch 244/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9620 - loss: 0.0749 - val_accuracy: 0.9770 - val_loss: 0.0489
# Epoch 245/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9620 - loss: 0.0734 - val_accuracy: 0.9779 - val_loss: 0.0417
# Epoch 246/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9599 - loss: 0.0798 - val_accuracy: 0.9789 - val_loss: 0.0473
# Epoch 247/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9594 - loss: 0.0808 - val_accuracy: 0.9763 - val_loss: 0.0466
# Epoch 248/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9616 - loss: 0.0759 - val_accuracy: 0.9792 - val_loss: 0.0435
# Epoch 249/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9612 - loss: 0.0794 - val_accuracy: 0.9801 - val_loss: 0.0525
# Epoch 250/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.0781 - val_accuracy: 0.9786 - val_loss: 0.0467
# Epoch 251/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9620 - loss: 0.0778 - val_accuracy: 0.9820 - val_loss: 0.0412
# Epoch 252/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9631 - loss: 0.0766 - val_accuracy: 0.9811 - val_loss: 0.0421
# Epoch 253/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9629 - loss: 0.0760 - val_accuracy: 0.9868 - val_loss: 0.0390
# Epoch 254/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9604 - loss: 0.0778 - val_accuracy: 0.9719 - val_loss: 0.0486
# Epoch 255/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9594 - loss: 0.0773 - val_accuracy: 0.9814 - val_loss: 0.0411
# Epoch 256/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9620 - loss: 0.0772 - val_accuracy: 0.9760 - val_loss: 0.0439
# Epoch 257/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.0767 - val_accuracy: 0.9763 - val_loss: 0.0505
# Epoch 258/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.0759 - val_accuracy: 0.9716 - val_loss: 0.0506
# Epoch 259/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9632 - loss: 0.0749 - val_accuracy: 0.9754 - val_loss: 0.0521
# Epoch 260/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9607 - loss: 0.0793 - val_accuracy: 0.9704 - val_loss: 0.0485
# Epoch 261/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9618 - loss: 0.0776 - val_accuracy: 0.9804 - val_loss: 0.0425
# Epoch 262/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.0767 - val_accuracy: 0.9763 - val_loss: 0.0483
# Epoch 263/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.0758 - val_accuracy: 0.9751 - val_loss: 0.0490
# Epoch 264/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9609 - loss: 0.0787 - val_accuracy: 0.9823 - val_loss: 0.0410
# Epoch 265/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9583 - loss: 0.0814 - val_accuracy: 0.9804 - val_loss: 0.0442
# Epoch 266/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.0754 - val_accuracy: 0.9738 - val_loss: 0.0520
# Epoch 267/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.0787 - val_accuracy: 0.9748 - val_loss: 0.0530
# Epoch 268/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9608 - loss: 0.0782 - val_accuracy: 0.9735 - val_loss: 0.0532
# Epoch 269/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9629 - loss: 0.0759 - val_accuracy: 0.9795 - val_loss: 0.0473
# Epoch 270/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9645 - loss: 0.0736 - val_accuracy: 0.9776 - val_loss: 0.0479
# Epoch 271/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9604 - loss: 0.0767 - val_accuracy: 0.9801 - val_loss: 0.0433
# Epoch 272/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9647 - loss: 0.0743 - val_accuracy: 0.9789 - val_loss: 0.0408
# Epoch 273/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.0741 - val_accuracy: 0.9905 - val_loss: 0.0374
# Epoch 274/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9652 - loss: 0.0726 - val_accuracy: 0.9779 - val_loss: 0.0464
# Epoch 275/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9618 - loss: 0.0755 - val_accuracy: 0.9789 - val_loss: 0.0473
# Epoch 276/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9618 - loss: 0.0784 - val_accuracy: 0.9738 - val_loss: 0.0459
# Epoch 277/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9627 - loss: 0.0790 - val_accuracy: 0.9792 - val_loss: 0.0444
# Epoch 278/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9610 - loss: 0.0817 - val_accuracy: 0.9722 - val_loss: 0.0536
# Epoch 279/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.0761 - val_accuracy: 0.9770 - val_loss: 0.0481
# Epoch 280/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9622 - loss: 0.0769 - val_accuracy: 0.9722 - val_loss: 0.0539
# Epoch 281/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9635 - loss: 0.0762 - val_accuracy: 0.9751 - val_loss: 0.0469
# Epoch 282/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9618 - loss: 0.0766 - val_accuracy: 0.9751 - val_loss: 0.0469
# Epoch 283/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.0753 - val_accuracy: 0.9735 - val_loss: 0.0473
# Epoch 284/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9627 - loss: 0.0719 - val_accuracy: 0.9767 - val_loss: 0.0477
# Epoch 285/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.0790 - val_accuracy: 0.9789 - val_loss: 0.0454
# Epoch 286/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.0748 - val_accuracy: 0.9710 - val_loss: 0.0561
# Epoch 287/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.0824 - val_accuracy: 0.9754 - val_loss: 0.0467
# Epoch 288/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9617 - loss: 0.0760 - val_accuracy: 0.9833 - val_loss: 0.0459
# Epoch 289/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.0776 - val_accuracy: 0.9801 - val_loss: 0.0490
# Epoch 290/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9617 - loss: 0.0808 - val_accuracy: 0.9745 - val_loss: 0.0474
# Epoch 291/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9624 - loss: 0.0794 - val_accuracy: 0.9773 - val_loss: 0.0511
# Epoch 292/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.0830 - val_accuracy: 0.9735 - val_loss: 0.0486
# Epoch 293/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9627 - loss: 0.0750 - val_accuracy: 0.9748 - val_loss: 0.0463
# Epoch 294/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9639 - loss: 0.0754 - val_accuracy: 0.9754 - val_loss: 0.0466
# Epoch 295/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9613 - loss: 0.0777 - val_accuracy: 0.9779 - val_loss: 0.0454
# Epoch 296/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9631 - loss: 0.0763 - val_accuracy: 0.9741 - val_loss: 0.0464
# Epoch 297/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9641 - loss: 0.0731 - val_accuracy: 0.9729 - val_loss: 0.0499
# Epoch 298/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9635 - loss: 0.0741 - val_accuracy: 0.9751 - val_loss: 0.0474
# Epoch 299/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.0784 - val_accuracy: 0.9833 - val_loss: 0.0399
# Epoch 300/300
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9620 - loss: 0.0779 - val_accuracy: 0.9748 - val_loss: 0.0493
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.97      0.94      2822
#          1.0       0.99      0.96      0.97      6794
#
#     accuracy                           0.96      9616
#    macro avg       0.95      0.97      0.96      9616
# weighted avg       0.97      0.96      0.96      9616
#
# [[2736   86]
#  [ 254 6540]]

# %%
# F1 Score 및 Accuracy 계산
accuracy = accuracy_score(y_test, y_pred_class)
f1 = f1_score(y_test, y_pred_class)

print(f'Accuracy: {accuracy:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.9646
# F1 Score: 0.9747
